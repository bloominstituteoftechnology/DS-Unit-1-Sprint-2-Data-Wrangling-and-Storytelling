# %%
# Make Explanatory Visualizations

from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
# fake re-creation

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('fivethirtyeight')

fake = pd.Series([38, 3, 2, 1, 2, 4, 6, 5, 5, 33], index=range(1,11))

fake.plot.bar(color='C1', width=0.9);

# %%
# using real data re-creation

df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')

# %%
pd.set_option('display.max_columns', 50)
df.head()
# Out:
#                     timestamp  respondents        category  \
# 0  2017-07-17 12:28:32.785639          402           Males
# 1  2017-07-17 12:28:33.025600           78         Females
# 2  2017-07-17 12:28:33.273919            4   Aged under 18
# 3  2017-07-17 12:28:33.495325            4  Males under 18
# 4  2017-07-17 12:28:33.722849          130      Aged 18-29
#
#                                                 link  average  mean  median  \
# 0   http://www.imdb.com/title/tt6322922/ratings-male      4.6   5.0       2
# 1  http://www.imdb.com/title/tt6322922/ratings-fe...      6.9   7.7      10
# 2  http://www.imdb.com/title/tt6322922/ratings-age_1      4.2   4.2       3
# 3  http://www.imdb.com/title/tt6322922/ratings-ma...      4.2   4.2       3
# 4  http://www.imdb.com/title/tt6322922/ratings-age_2      6.3   6.5       9
#
#    1_votes  2_votes  3_votes  4_votes  5_votes  6_votes  7_votes  8_votes  \
# 0      197        7        7        3        7        7       11        8
# ...

# %%
df.shape
# Out:
# (80053, 27)

# %%
df.sample(1).T
# Out:
#                                                          25847
# timestamp                           2017-08-10 03:30:02.929039
# respondents                                                188
# category                                               Females
# link         http://www.imdb.com/title/tt6322922/ratings-fe...
# average                                                    6.6
# mean                                                       7.1
# median                                                      10
# 1_votes                                                     45
# 2_votes                                                      2
# 3_votes                                                      3
# 4_votes                                                      3
# 5_votes                                                      3
# 6_votes                                                      4
# 7_votes                                                      7
# ...

# %%
df.dtypes
# Out:
# timestamp       object
# respondents      int64
# category        object
# link            object
# average        float64
# mean           float64
# median           int64
# 1_votes          int64
# 2_votes          int64
# 3_votes          int64
# 4_votes          int64
# 5_votes          int64
# 6_votes          int64
# 7_votes          int64
# 8_votes          int64
# 9_votes          int64
# 10_votes         int64
# 1_pct          float64
# 2_pct          float64
# 3_pct          float64
# 4_pct          float64
# 5_pct          float64
# 6_pct          float64
# 7_pct          float64
# 8_pct          float64
# 9_pct          float64
# 10_pct         float64
# dtype: object

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp'].describe()
# Out:
# count                          80053
# unique                         80053
# top       2017-07-24 23:00:02.760781
# freq                               1
# first     2017-07-17 12:28:32.785639
# last      2017-08-29 23:10:06.218251
# Name: timestamp, dtype: object

# %%
df.set_index('timestamp', inplace=True)
df['2017-08-29']
# Out:
#                             respondents            category  \
# timestamp
# 2017-08-29 00:00:02.248882         1682               Males
# 2017-08-29 00:00:02.499363          257             Females
# 2017-08-29 00:00:02.727204           15       Aged under 18
# 2017-08-29 00:00:03.024270           13      Males under 18
# 2017-08-29 00:00:03.248207            2    Females under 18
# 2017-08-29 00:00:03.441529          450          Aged 18-29
# 2017-08-29 00:00:03.636825          402    Males Aged 18-29
# 2017-08-29 00:00:03.839446           41  Females Aged 18-29
# 2017-08-29 00:00:04.030663          771          Aged 30-44
# 2017-08-29 00:00:04.225962          679    Males Aged 30-44
# 2017-08-29 00:00:04.539312           76  Females Aged 30-44
# 2017-08-29 00:00:04.776104          539            Aged 45+
# 2017-08-29 00:00:04.973766          421      Males Aged 45+
# 2017-08-29 00:00:05.176998          109    Females Aged 45+
# ...

# %%
df['category'].value_counts()
# Out:
# Females Aged 45+      4216
# Females Aged 30-44    4216
# US users              4216
# Aged 45+              4216
# Females               4216
# Aged 30-44            4216
# IMDb users            4216
# Non-US users          4216
# IMDb staff            4216
# Males under 18        4216
# Males                 4216
# Males Aged 30-44      4216
# Aged under 18         4216
# Females Aged 18-29    4216
# Top 1000 voters       4216
# Males Aged 45+        4216
# Males Aged 18-29      4216
# Aged 18-29            4216
# Females under 18      4165
# Name: category, dtype: int64

# %%
lastday = df['2017-08-29']
lastday_filtered = lastday[lastday['category'] == 'IMDb users']
lastday_filtered.head(10)
# Out:
#                             respondents    category  \
# timestamp
# 2017-08-29 00:00:06.288486         2646  IMDb users
# 2017-08-29 00:10:06.763461         2646  IMDb users
# 2017-08-29 00:20:05.745307         2646  IMDb users
# 2017-08-29 00:30:05.818552         2646  IMDb users
# 2017-08-29 00:40:06.180928         2646  IMDb users
# 2017-08-29 00:50:05.826082         2646  IMDb users
# 2017-08-29 01:00:05.483262         2646  IMDb users
# 2017-08-29 01:10:06.038644         2646  IMDb users
# 2017-08-29 01:20:05.807155         2646  IMDb users
# 2017-08-29 01:30:05.317814         2646  IMDb users
#
#                                                                    link  \
# timestamp
# 2017-08-29 00:00:06.288486  http://www.imdb.com/title/tt6322922/ratings
# 2017-08-29 00:10:06.763461  http://www.imdb.com/title/tt6322922/ratings
# 2017-08-29 00:20:05.745307  http://www.imdb.com/title/tt6322922/ratings
# 2017-08-29 00:30:05.818552  http://www.imdb.com/title/tt6322922/ratings
# ...

# %%
lastday_filtered.respondents.plot();

# %%
# getting data for last cumulative timestamp on August 29

final = lastday_filtered.tail(1)
final.T
# Out:
# timestamp                     2017-08-29 23:10:06.218251
# respondents                                         2662
# category                                      IMDb users
# link         http://www.imdb.com/title/tt6322922/ratings
# average                                              5.4
# mean                                                 5.6
# median                                                 7
# 1_votes                                             1021
# 2_votes                                               69
# 3_votes                                               38
# 4_votes                                               25
# 5_votes                                               55
# 6_votes                                              110
# 7_votes                                              154
# 8_votes                                              147
# 9_votes                                              146
# ...

# %%
pct_columns = ['1_pct', '2_pct', '3_pct', '4_pct', '5_pct', '6_pct',
              '7_pct','8_pct','9_pct','10_pct']

# %%
plot_data = final[pct_columns].T

# %%
plot_data.index = range(1, 11)
plot_data
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1                                38.4
# 2                                 2.6
# 3                                 1.4
# 4                                 0.9
# 5                                 2.1
# 6                                 4.1
# 7                                 5.8
# 8                                 5.5
# 9                                 5.5
# 10                               33.7

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure()

ax = plot_data.plot.bar(color='#ef7030', width =0.9, legend=False)

ax.set(yticks=range(0, 50, 10), facecolor='#f9f9f9')
fig.patch.set_facecolor('#f9f9f9')

plt.ylabel('Percent of total votes', fontsize=9, fontweight='bold')
plt.xlabel('Rating', fontsize=9, fontweight='bold')

ax.text(x=-2, y=46, s="'An Inconvenient Sequel: Truth to Power' is divisive",
       fontsize=12, fontweight='bold')
ax.text(x=-2, y=43, s='IMDb ratings for the film as of Aug 29',
       fontsize=10)
ax.tick_params(labelrotation=0);

# %%
display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
from IPython.display import display, Image

url2 = 'https://fivethirtyeight.com/wp-content/uploads/2014/04/pulitzer-nate2.png'
example2 = Image(url=url2, width=400)

display(example2)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2014/04/pulitzer-nate2.png" width="400"/>

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/mmastin/data/master/pulitzer/pulitzer-circulation-data.csv')

# %%
df2.head()
# Out:
#              Newspaper Daily Circulation, 2004 Daily Circulation, 2013  \
# 0            USA Today               2,192,098               1,674,306
# 1  Wall Street Journal               2,101,017               2,378,827
# 2       New York Times               1,119,027               1,865,318
# 3    Los Angeles Times                 983,727                 653,868
# 4      Washington Post                 760,034                 474,767
#
#   Change in Daily Circulation, 2004-2013  \
# 0                                   -24%
# 1                                   +13%
# 2                                   +67%
# 3                                   -34%
# 4                                   -38%
#
#    Pulitzer Prize Winners and Finalists, 1990-2003  \
# 0                                                1
# 1                                               30
# 2                                               55
# 3                                               44
# ...

# %%
df2.dtypes
# Out:
# Newspaper                                          object
# Daily Circulation, 2004                            object
# Daily Circulation, 2013                            object
# Change in Daily Circulation, 2004-2013             object
# Pulitzer Prize Winners and Finalists, 1990-2003     int64
# Pulitzer Prize Winners and Finalists, 2004-2014     int64
# Pulitzer Prize Winners and Finalists, 1990-2014     int64
# dtype: object

# %%
df2['Change in Daily Circulation, 2004-2013'] = df2['Change in Daily Circulation, 2004-2013'].str.replace('%', '')

# %%
df2.dtypes
# Out:
# Newspaper                                          object
# Daily Circulation, 2004                            object
# Daily Circulation, 2013                            object
# Change in Daily Circulation, 2004-2013             object
# Pulitzer Prize Winners and Finalists, 1990-2003     int64
# Pulitzer Prize Winners and Finalists, 2004-2014     int64
# Pulitzer Prize Winners and Finalists, 1990-2014     int64
# dtype: object

# %%
df2['Change in Daily Circulation, 2004-2013'] = df2['Change in Daily Circulation, 2004-2013'].astype(int)

# %%
df2.isnull().sum()
# Out:
# Newspaper                                          0
# Daily Circulation, 2004                            0
# Daily Circulation, 2013                            0
# Change in Daily Circulation, 2004-2013             0
# Pulitzer Prize Winners and Finalists, 1990-2003    0
# Pulitzer Prize Winners and Finalists, 2004-2014    0
# Pulitzer Prize Winners and Finalists, 1990-2014    0
# dtype: int64

# %%
# plot_data_pulitzer = df2['Pulitzer Prize Winners and Finalists, 1990-2014'].T
# plot_data_pulitzer

# %%
# plot_data_circulation

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure()
from pylab import *

y = [-100, -75, -50, -25, 0, 25, 50, 75, 100]
x = [0, 25, 50, 75, 100, 125]

plt.scatter(df2['Pulitzer Prize Winners and Finalists, 1990-2014'], 
            df2['Change in Daily Circulation, 2004-2013'], 
            color='#ed713a', edgecolors='white')

# ax.set()

plt.xlabel('Pulitzer winners and finalists', fontsize=9)

plt.yticks(y, rotation='horizontal', fontsize=8, fontweight='bold')
plt.xticks(x, rotation='horizontal', fontsize=8, fontweight='bold')

# plt.text("'Pulitzer Prizes Don't Lure Readers'", x=-2, y= 125)

plt.suptitle("Pulitzer Prizes Don't Lure Readers", x=0.36, fontsize=15, fontweight='bold')
plt.title('Change in circulation vs Pulitzer winners and finalists among the top 50 newspapers', multialignment='left', fontsize=10)
             
#              , loc='left', 
#           fontsize=15, fontweight='bold')
# plt.title('asdfl;kasdf', loc='left')

# fig.patch.set_facecolor('#f9f9f9')


# ax.tick_params(axis='both,', which='major', labelsize=9);
# ax.text(x=-2, y=46, s="'An Inconvenient Sequel: Truth To Power' is divisive",
#         fontsize=12, fontweight='bold')
# ax.text(x=-2, y=43, s='IMDb ratings for the film as of Aug. 29',
#         fontsize=11)
# Out:
# Text(0.5, 1.0, 'Change in circulation vs Pulitzer winners and finalists among the top 50 newspapers')

# %%
display(example2)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2014/04/pulitzer-nate2.png" width="400"/>
