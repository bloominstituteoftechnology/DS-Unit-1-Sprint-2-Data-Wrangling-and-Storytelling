# %% [markdown]
# <a href="https://colab.research.google.com/github/eyvonne/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module1-join-and-reshape-data/Eyve_Geo_LS_DS7_121_Join_and_Reshape_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Join and Reshape datasets
#
# Objectives
# - concatenate data with pandas
# - merge data with pandas
# -  understand tidy data formatting
# -  melt and pivot data with pandas
#
# Links
# - [Pandas Cheat Sheet](https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf)
# - [Tidy Data](https://en.wikipedia.org/wiki/Tidy_data)
#   - Combine Data Sets: Standard Joins
#   - Tidy Data
#   - Reshaping Data
# - Python Data Science Handbook
#   - [Chapter 3.6](https://jakevdp.github.io/PythonDataScienceHandbook/03.06-concat-and-append.html), Combining Datasets: Concat and Append
#   - [Chapter 3.7](https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html), Combining Datasets: Merge and Join
#   - [Chapter 3.8](https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html), Aggregation and Grouping
#   - [Chapter 3.9](https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html), Pivot Tables
#
# Reference
# - Pandas Documentation: [Reshaping and Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html)
# - Modern Pandas, Part 5: [Tidy Data](https://tomaugspurger.github.io/modern-5-tidy.html)

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-08-12 21:56:04--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.109.133
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz.2’
#
# instacart_online_gr 100%[===================>] 196.03M  96.5MB/s    in 2.0s
#
# 2019-08-12 21:56:06 (96.5 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz.2’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 502 staff 2.6K May  2  2017 aisles.csv
# -rw-r--r-- 1 502 staff  270 May  2  2017 departments.csv
# -rw-r--r-- 1 502 staff 551M May  2  2017 order_products__prior.csv
# -rw-r--r-- 1 502 staff  24M May  2  2017 order_products__train.csv
# -rw-r--r-- 1 502 staff 104M May  2  2017 orders.csv
# -rw-r--r-- 1 502 staff 2.1M May  2  2017 products.csv

# %% [markdown]
# # Assignment
#
# ## Join Data Practice
#
# These are the top 10 most frequently ordered products. How many times was each ordered?
#
# 1. Banana
# 2. Bag of Organic Bananas
# 3. Organic Strawberries
# 4. Organic Baby Spinach
# 5. Organic Hass Avocado
# 6. Organic Avocado
# 7. Large Lemon
# 8. Strawberries
# 9. Limes
# 10. Organic Whole Milk
#
# First, write down which columns you need and which dataframes have them.
#
# Next, merge these into a single dataframe.
#
# Then, use pandas functions from the previous lesson to get the counts of the top 10 most frequently ordered products.

# %% [markdown]
# Columns Needed/Location:
# - product ID/products.csv
# - product name/products.csv
# - product id with order/order products.

# %%
import pandas as pd
pd.options.display.max_rows=150

# %%
#read in and join up the orders information
df1=pd.read_csv('order_products__prior.csv')
df2=pd.read_csv('order_products__train.csv')
ordersDF=pd.concat([df1,df2])
ordersDF.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#read in product name information 
products=pd.read_csv('products.csv')
products.head()
# Out:
#    product_id  ... department_id
# 0           1  ...            19
# 1           2  ...            13
# 2           3  ...             7
# 3           4  ...             1
# 4           5  ...            13
#
# [5 rows x 4 columns]

# %%
#create a dataframe of only the top ten items
topTen=ordersDF['product_id'].value_counts().head(10).index.tolist()
topTenDF=products[products['product_id'].isin(topTen)]
#remove any order lines that don't have a product in the top ten (make it go faster)
ordersSubset=ordersDF[ordersDF['product_id'].isin(topTen)]
topTenDF['product_id'].value_counts()
# Out:
# 21903    1
# 16797    1
# 47766    1
# 47626    1
# 47209    1
# 13176    1
# 26209    1
# 27845    1
# 24852    1
# 21137    1
# Name: product_id, dtype: int64

# %%
ordersSubset.head()
# Out:
#     order_id  product_id  add_to_cart_order  reordered
# 12         3       21903                  4          1
# 30         5       13176                  1          1
# 51         5       47209                 22          0
# 77        10       24852                  1          1
# 80        10       47766                  4          1

# %%
topTenDF['product_id']
# Out:
# 13175    13176
# 16796    16797
# 21136    21137
# 21902    21903
# 24851    24852
# 26208    26209
# 27844    27845
# 47208    47209
# 47625    47626
# 47765    47766
# Name: product_id, dtype: int64

# %%
columns=['product_id','product_name']

merged=pd.merge(ordersSubset['product_id'], topTenDF[columns], how='inner', on='product_id')
merged.head()
topTenRate=merged['product_name'].value_counts()

# %%
#this is a list of the top ordered items and how often they were ordered 
topTenRate
# Out:
# Banana                    491291
# Bag of Organic Bananas    394930
# Organic Strawberries      275577
# Organic Baby Spinach      251705
# Organic Hass Avocado      220877
# Organic Avocado           184224
# Large Lemon               160792
# Strawberries              149445
# Limes                     146660
# Organic Whole Milk        142813
# Name: product_name, dtype: int64

# %% [markdown]
# ## Reshape Data Section
#
# - Replicate the lesson code
# - Complete the code cells we skipped near the beginning of the notebook
# - Table 2 --> Tidy
# - Tidy --> Table 2
# - Load seaborn's `flights` dataset by running the cell below. Then create a pivot table showing the number of passengers by month and year. Use year for the index and month for the columns. You've done it right if you get 112 passengers for January 1949 and 432 passengers for December 1960.

# %%
import numpy as np

# %%
#set up table 2 
table1 = pd.DataFrame(
    [[np.nan, 2],
     [16,    11], 
     [3,      1]],
    index=['John Smith', 'Jane Doe', 'Mary Johnson'], 
    columns=['treatmenta', 'treatmentb'])

table2 = table1.T
table2
# Out:
#             John Smith  Jane Doe  Mary Johnson
# treatmenta         NaN      16.0           3.0
# treatmentb         2.0      11.0           1.0

# %%
treat=table2.index.to_list()

# %%
cols=table2.columns.to_list()
cols
# Out:
# ['John Smith', 'Jane Doe', 'Mary Johnson']

# %%
table2=table2.reset_index()

# %%
table2
# Out:
#         index  John Smith  Jane Doe  Mary Johnson
# 0  treatmenta         NaN      16.0           3.0
# 1  treatmentb         2.0      11.0           1.0

# %%
tidy=table2.melt(id_vars='index', value_vars=cols)
tidy
# Out:
#         index      variable  value
# 0  treatmenta    John Smith    NaN
# 1  treatmentb    John Smith    2.0
# 2  treatmenta      Jane Doe   16.0
# 3  treatmentb      Jane Doe   11.0
# 4  treatmenta  Mary Johnson    3.0
# 5  treatmentb  Mary Johnson    1.0

# %%
import seaborn as sns

# %%
flights = sns.load_dataset('flights')

# %%
##### YOUR CODE HERE #####

# %%
flights.pivot_table(index='year', columns='month', values='passengers')
# Out:
# month  January  February  March  April  ...  September  October  November  December
# year                                    ...
# 1949       112       118    132    129  ...        136      119       104       118
# 1950       115       126    141    135  ...        158      133       114       140
# 1951       145       150    178    163  ...        184      162       146       166
# 1952       171       180    193    181  ...        209      191       172       194
# 1953       196       196    236    235  ...        237      211       180       201
# 1954       204       188    235    227  ...        259      229       203       229
# 1955       242       233    267    269  ...        312      274       237       278
# 1956       284       277    317    313  ...        355      306       271       306
# 1957       315       301    356    348  ...        404      347       305       336
# 1958       340       318    362    348  ...        404      359       310       337
# 1959       360       342    406    396  ...        463      407       362       405
# 1960       417       391    419    461  ...        508      461       390       432
#
# [12 rows x 12 columns]

# %% [markdown]
# ## Join Data Stretch Challenge
#
# The [Instacart blog post](https://tech.instacart.com/3-million-instacart-orders-open-sourced-d40d29ead6f2) has a visualization of "**Popular products** purchased earliest in the day (green) and latest in the day (red)."
#
# The post says,
#
# > "We can also see the time of day that users purchase specific products.
#
# > Healthier snacks and staples tend to be purchased earlier in the day, whereas ice cream (especially Half Baked and The Tonight Dough) are far more popular when customers are ordering in the evening.
#
# > **In fact, of the top 25 latest ordered products, the first 24 are ice cream! The last one, of course, is a frozen pizza.**"
#
# Your challenge is to reproduce the list of the top 25 latest ordered popular products.
#
# We'll define "popular products" as products with more than 2,900 orders.

# %%
##### YOUR CODE HERE #####
#create a list of the most common items purchased 
values=ordersDF['product_id'].value_counts()
orderRate=values[values>29000]
orderRate=orderRate.reset_index()
orderRate=orderRate.rename(columns={'index':'product_id','product_id':'purchase_rate'})
orderRate.head()
# Out:
#    product_id  purchase_rate
# 0       24852         491291
# 1       13176         394930
# 2       21137         275577
# 3       21903         251705
# 4       47209         220877

# 67         8424  ...                                     Broccoli Crown
# 68        27521  ...                   Organic Lacinato (Dinosaur) Kale
# 69        33198  ...                    Sparkling Natural Mineral Water
# 70         8174  ...                               Organic Navel Orange
# 71        44142  ...                                          Red Onion
# 72        20114  ...                                   Jalapeno Peppers
# 73        27344  ...                               Uncured Genoa Salami
# 74        11520  ...                                Large Alfresco Eggs
# 75        29487  ...                                        Roma Tomato
# 76        18465  ...        Organic Grade A Free Range Large Brown Eggs
# 77        28199  ...                                   Clementines, Bag
# 78        15290  ...                                 Orange Bell Pepper
# 79        46906  ...                         Grape White/Green Seedless
# 80         9839  ...                                   Organic Broccoli
# 81        27156  ...                                Organic Black Beans
# 82         3957  ...                             100% Raw Coconut Water
# 83        43122  ...                              Organic Bartlett Pear
# 84        23909  ...                                2% Reduced Fat Milk
# 85        34358  ...                                             Garlic
# 86         4799  ...                                  Shredded Parmesan
# 87         9387  ...                                Granny Smith Apples
# 88        16759  ...                               Organic Carrot Bunch
# 89          196  ...                                               Soda
# 90        42736  ...                                    Unsalted Butter
# 91         4210  ...                                         Whole Milk
# 92        38689  ...                           Organic Reduced Fat Milk
# 93        41787  ...                                     Bartlett Pears
# 94        47144  ...     Unsweetened Original Almond Breeze Almond Milk
# 95        41220  ...                            Organic Romaine Lettuce
# 96         7781  ...  Organic Sticks Low Moisture Part Skim Mozzarel...
# 97        33000  ...                                  Pure Irish Butter
# 98        20995  ...                           Organic Broccoli Florets
# 99        21709  ...                              Sparkling Lemon Water
# 100       40604  ...                               Feta Cheese Crumbles
# 101       19678  ...                              Organic Russet Potato
# 102       30233  ...        Organic Large Brown Grade AA Cage Free Eggs
# 103       34243  ...                              Organic Baby Broccoli
# 104       37687  ...                                 Organic Spring Mix
# 105       24489  ...                         Organic Whole Strawberries
# 106       42828  ...                               Whipped Cream Cheese
# 107         432  ...                  Vanilla Almond Breeze Almond Milk
# 108        6184  ...                                        Clementines
# 109        5479  ...                    Italian Sparkling Mineral Water
# 110       16185  ...                               Sharp Cheddar Cheese
# 111       42768  ...                             Organic Garbanzo Beans
# 112       17948  ...                    Frozen Organic Wild Blueberries
# 113       33754  ...  Total 2% with Strawberry Lowfat Greek Strained...
# 114        8193  ...                                      Russet Potato
# 115       19348  ...                                      Fat Free Milk
# 116       26369  ...                                Organic Roma Tomato
# 117       42585  ...                            Organic Extra Firm Tofu
# 118       14992  ...                                        Green Beans
# 119       14947  ...                               Pure Sparkling Water
# 120       22963  ...                      Organic Roasted Turkey Breast
# 121       28849  ...                          No Salt Added Black Beans
# 122        8021  ...                         100% Recycled Paper Towels
#
# [123 rows x 3 columns]

# %%
#this data has the times of orders 
orders=pd.read_csv('orders.csv')
orders.head()
# Out:
#    order_id  user_id  ... order_hour_of_day  days_since_prior_order
# 0   2539329        1  ...                 8                     NaN
# 1   2398795        1  ...                 7                    15.0
# 2    473747        1  ...                12                    21.0
# 3   2254736        1  ...                 7                    29.0
# 4    431534        1  ...                15                    28.0
#
# [5 rows x 7 columns]

# %%
#combine into one dataframe that has all the info we need in it 
# 33819056   2266710                 18       41213
# 33819057   2266710                 18       23800
# 33819058   2266710                 18       24852
# 33819059   2266710                 18       13838
# 33819060   2266710                 18       31130
# 33819061   1854736                 10        6846
# 33819062   1854736                 10        9405
# 33819063   1854736                 10       41213
# 33819064   1854736                 10       24852
# 33819065   1854736                 10       19348
# 33819066   1854736                 10       15700
# 33819067   1854736                 10       40310
# 33819068   1854736                 10       48370
# 33819069    626363                 12        6846
# 33819070    626363                 12       24852
# 33819071    626363                 12        9405
# 33819072    626363                 12       19348
# 33819073    626363                 12       41213
# 33819074    626363                 12       15700
# 33819075    626363                 12       38167
# 33819076    626363                 12       26209
# 33819077    626363                 12       33129
# 33819078    626363                 12       43961
# 33819079    626363                 12       23800
# 33819080    626363                 12       13838
# 33819081    626363                 12       48742
# 33819082    626363                 12       23594
# 33819083    626363                 12       20590
# 33819084    626363                 12       16168
# 33819085    626363                 12       33351
# 33819086    626363                 12        5622
# 33819087    626363                 12       23039
# 33819088    626363                 12       14727
# 33819089   2977660                 12       24852
# 33819090   2977660                 12        9405
# 33819091   2977660                 12       16168
# 33819092   2977660                 12       39216
# 33819093   2977660                 12       14197
# 33819094   2977660                 12       38730
# 33819095   2977660                 12       31477
# 33819096   2977660                 12        6567
# 33819097   2977660                 12       22920
# 33819098    272231                 14        6846
# 33819099    272231                 14        9405
# 33819100    272231                 14       24852
# 33819101    272231                 14       40603
# 33819102    272231                 14       15655
# 33819103    272231                 14       42606
# 33819104    272231                 14       37966
# 33819105    272231                 14       39216
#
# [33819106 rows x 3 columns]

# %%
final=pd.merge(timeOrderDF, orderRate[columns])

# %%
final.columns.to_list()
# Out:
# ['order_id', 'order_hour_of_day', 'product_id', 'product_name']

# %%
ct=pd.crosstab(final['product_name'],final['order_hour_of_day'], normalize='index')
ct
# Out:
# order_hour_of_day                                         0   ...        23
# product_name                                                  ...
# 100% Raw Coconut Water                              0.008454  ...  0.013292
# 100% Recycled Paper Towels                          0.006885  ...  0.011912
# 100% Whole Wheat Bread                              0.005514  ...  0.010220
# 2% Reduced Fat Milk                                 0.006549  ...  0.010096
# Apple Honeycrisp Organic                            0.006314  ...  0.011630
# Asparagus                                           0.006999  ...  0.012804
# Bag of Organic Bananas                              0.007184  ...  0.012909
# Banana                                              0.005933  ...  0.011372
# Bartlett Pears                                      0.006035  ...  0.012589
# Blueberries                                         0.006830  ...  0.013094
# Boneless Skinless Chicken Breasts                   0.006893  ...  0.012526
# Broccoli Crown                                      0.006848  ...  0.012184
# Bunched Cilantro                                    0.006322  ...  0.012139
# Carrots                                             0.007736  ...  0.013784
# Clementines                                         0.005871  ...  0.008822
# Clementines, Bag                                    0.007336  ...  0.012953
# Cucumber Kirby                                      0.007551  ...  0.012534
# Extra Virgin Olive Oil                              0.007110  ...  0.012270
# Fat Free Milk                                       0.006543  ...  0.012531
# Feta Cheese Crumbles                                0.006864  ...  0.013609
# Fresh Cauliflower                                   0.006978  ...  0.013632
# Frozen Organic Wild Blueberries                     0.007427  ...  0.013335
# Garlic                                              0.008485  ...  0.015206
# Organic Roasted Turkey Breast                       0.006032  ...  0.012404
# Organic Roma Tomato                                 0.009208  ...  0.016909
# Organic Romaine Lettuce                             0.007383  ...  0.013517
# Organic Russet Potato                               0.006586  ...  0.013231
# Organic Small Bunch Celery                          0.007014  ...  0.012614
# Organic Spring Mix                                  0.008180  ...  0.015967
# Organic Sticks Low Moisture Part Skim Mozzarell...  0.005569  ...  0.012658
# Organic Strawberries                                0.006884  ...  0.013343
# Organic Tomato Cluster                              0.008335  ...  0.013198
# Organic Unsweetened Almond Milk                     0.006925  ...  0.012252
# Organic Whole Milk                                  0.006603  ...  0.013094
# Organic Whole Strawberries                          0.007778  ...  0.013381
# Organic Whole String Cheese                         0.005611  ...  0.011335
# Organic Yellow Onion                                0.006150  ...  0.011842
# Organic Zucchini                                    0.006992  ...  0.013783
# Original Hummus                                     0.006984  ...  0.012970
# Pure Irish Butter                                   0.006924  ...  0.012435
# Pure Sparkling Water                                0.004432  ...  0.008664
# Raspberries                                         0.006681  ...  0.012476
# Red Onion                                           0.007442  ...  0.011736
# Red Peppers                                         0.006548  ...  0.011876
# Red Vine Tomato                                     0.007327  ...  0.013117
# Roma Tomato                                         0.007660  ...  0.013423
# Russet Potato                                       0.006833  ...  0.012170
# Seedless Red Grapes                                 0.007009  ...  0.013107
# Sharp Cheddar Cheese                                0.006331  ...  0.011262
# Shredded Parmesan                                   0.005970  ...  0.012205
# Small Hass Avocado                                  0.006734  ...  0.010897
# Soda                                                0.004853  ...  0.007641
# Sparkling Lemon Water                               0.003975  ...  0.008185
# Sparkling Natural Mineral Water                     0.006304  ...  0.012339
# Sparkling Water Grapefruit                          0.004543  ...  0.008871
# Spring Water                                        0.008609  ...  0.013599
# Strawberries                                        0.006491  ...  0.012848
# Total 2% with Strawberry Lowfat Greek Strained ...  0.005540  ...  0.012765
# Uncured Genoa Salami                                0.005825  ...  0.010934
# Unsalted Butter                                     0.006388  ...  0.013126
# Unsweetened Almondmilk                              0.006514  ...  0.011442
# Unsweetened Original Almond Breeze Almond Milk      0.005826  ...  0.012483
# Vanilla Almond Breeze Almond Milk                   0.006209  ...  0.010803
# Whipped Cream Cheese                                0.006229  ...  0.012581
# Whole Milk                                          0.005789  ...  0.011767
# Yellow Onions                                       0.006642  ...  0.011920
#
# [123 rows x 24 columns]

# %%
ct.T.plot(legend=False);

# %% [markdown]
# ## Reshape Data Stretch Challenge
#
# _Try whatever sounds most interesting to you!_
#
# - Replicate more of Instacart's visualization showing "Hour of Day Ordered" vs "Percent of Orders by Product"
# - Replicate parts of the other visualization from [Instacart's blog post](https://tech.instacart.com/3-million-instacart-orders-open-sourced-d40d29ead6f2), showing "Number of Purchases" vs "Percent Reorder Purchases"
# - Get the most recent order for each user in Instacart's dataset. This is a useful baseline when [predicting a user's next order](https://www.kaggle.com/c/instacart-market-basket-analysis)
# - Replicate parts of the blog post linked at the top of this notebook: [Modern Pandas, Part 5: Tidy Data](https://tomaugspurger.github.io/modern-5-tidy.html)

# %%
##### YOUR CODE HERE #####
