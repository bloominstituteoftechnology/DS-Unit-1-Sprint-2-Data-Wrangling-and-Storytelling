# %% [markdown]
# <a href="https://colab.research.google.com/github/shmilyface/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/Find_Portfolio_Ideas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Autism Research
# ##You
# What do you care about?
#
#
#
# >Finding ways to use Data Science to improve the lives of those in the autism community.
#
#
#
# What do you know about?
# >ABA therapy, social psychology
#
# What decisions do you face?
# >What data will I use? What question is appropriate for me to ask, as an ally? How am I personally biased, and how is that stopping me from choosing relevant data?
#
# Real Life example: What cities have top autism communities, AND lots of job opportunity?
#
#
# #Seven templates
# ##Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# Geographic Variation
#
# Trend related to the news
#
# Who does that?
#
# **Answering a question people care about**
#
# Valuable to businesses
#
# What's the most popular?
#
# Cost/Money rankings***
#
# ##Misconceptions
# What misconceptions do people have about your topic?
#
# *That Autism is diagnosed on a linear spectrum.
#
# *That autistic individuals are all savants.
#
# *That vaccines cause autism
#
# *That autism is curable
#
# *That autism is only diagnosable in young persons
#
# *That women who are high functioning autistic aren't really autistic.
#
# *Social Skills != that child isn't moderately autistic.
#
# *We have tons of resources
#
# *We have community support for autistic individuals post childhood
#
# *Representation in medical and emergency protocols
#
# *Enforcement of laws in place for disabled.
#
#
#
# ##Examples
# What data storytelling example inspires you?
# .http://www.caseforinclusion.org/data/state-scorecards
#
#
# Could you do a new hypothesis, for the same question?
# Eh....
#
# Could you do a new question, for the same topic?
# Yes
#
# Could you do a new topic, with the same "style"?
# Yes
#
# ##Data
# Where could you search for data about your topic?
# http://www.caseforinclusion.org/data/state-scorecards
#
# >I know its the same as the example that inspired me, but it inspired me mostly because its incredibly well documented, multiple years of publications, references, and access to data. Unlike Autism Speaks, who's data was based on communicating with parents of autistics, and not including autistics an actual, over 18 voice in the survey, no references included because the survey was done via surveymonkey, no questions shared to verify bias, etc.
#
# #Assignment!
# Fill out the above template twice, for two different ideas.
#
# ###Then compare and contrast and select one as the idea you're leaning towards working on for your project week.

# %% [markdown]
# # Story Telling : Diagnosis Rates by Gender
# ##You
# What do you care about?
#
#
#
# >Mental Health /Access to Resources
#
#
#
# What do you know about?
# >ABA therapy, social psychology, trauma therapy
#
# What decisions do you face?
# >What question do I want to answer? # of visits before women are diagnosed versus men for similar issues
# >Where can I have access to this data
# >What unifying factors do I need to consider?
#
#
# #Seven templates
# ##Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# Geographic Variation
#
# Trend related to the news
#
# Who does that?
#
# **Answering a question people care about**
#
# Valuable to businesses
#
# What's the most popular?
#
# **Cost/Money rankings**
#
# ##Misconceptions
# What misconceptions do people have about your topic?
#
#
# *Women are hysterical by nature
#
# *Women are overly anxious by nature
#
# *Women have no idea what their issues are
#
# Truth is:
#
# *Women are dying because they are being dismissed
#
# *Women fight to be diagnosed because they are less believed by doctors
#
# *Women of color and transgender women are doubly at risk.
#
# How does this compare to men? Men of color?
#
#
#
# ##Examples
# What data storytelling example inspires you?
# >https://www.health.harvard.edu/blog/women-and-pain-disparities-in-experience-and-treatment-2017100912562
#
#
# Could you do a new hypothesis, for the same question?
# Eh....
#
# Could you do a new question, for the same topic?
# YES
#
# Could you do a new topic, with the same "style"?
# Ehh
#
# ##Data
# where could you search for data about your topic?
# >medical journals, several medical data repositories listed for resources.
#
#
#
# #Assignment!
# Fill out the above template twice, for two different ideas.
#
# ###Then compare and contrast and select one as the idea you're leaning towards working on for your project week.

# %% [markdown]
# **Challenges and Stretch Goals**
#
# I've decided to continue looking for sources and information for both for the weekend, before I make a decision on which dataset I will use, although I'm leaning heavily towards autism research. Given time I think I can find more in-depth and surprising statistical questions!
#
# Github Page: https://shmilyface.github.io/
# Twitter: https://twitter.com/Stephan51162874
# LinkedIn: https://www.linkedin.com/in/stephaniemillerwa/
#
# Check out the Github for About me, customization, links to social outlets
