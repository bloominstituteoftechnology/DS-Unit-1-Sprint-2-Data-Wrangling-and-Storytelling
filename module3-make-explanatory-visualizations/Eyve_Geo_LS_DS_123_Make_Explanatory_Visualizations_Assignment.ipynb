# %% [markdown]
# <a href="https://colab.research.google.com/github/eyvonne/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module3-make-explanatory-visualizations/Eyve_Geo_LS_DS_123_Make_Explanatory_Visualizations_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# ### 2) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/) (try the [`altair`](https://altair-viz.github.io/gallery/index.html#maps) library)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/) (try the [`statsmodels`](https://www.statsmodels.org/stable/index.html) library)
# - or another example of your choice!

# %%
# Your Work Here

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')
col=df.columns.to_list()
col=col[-10:] 
fake=df.loc[80052, col]

# %%
# Your Work Here
fig=plt.figure()
ax=fake.plot.bar(color='C1', width = .9, zorder=3)

#copy the stuff from class
ax.patch.set_facecolor('white')
fig.patch.set_facecolor('white')
plt.title("'An Inconvient Sequel: Truth to Power' is devisive", fontsize=12, fontweight='bold', y=1.1, x=-.1, loc='left')
ax.text(-1.7,42, 'IMDb ratings for the film as of Aug. 29', fontsize=12)
ax.set_xticklabels(range(1,11), rotation=0, color='#BCBCBC')
ax.set_yticklabels(range(0,60,10), color='#BCBCBC')
ax.set_yticks(range(0,40,10))
plt.xlabel('Rating',fontsize=10, fontweight='bold', color='black')
plt.ylabel('Percent of total votes',fontsize=10, fontweight='bold', color='black')
#remove the outer bars
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.tick_params('both', color='#BCBCBC')

#show the grid
plt.grid(True)
ax.grid(zorder=0, color='#BCBCBC')

#add the text at the bottom
plt.text(-1.7,-8.5, 'FiveThirtyEight', color='grey', fontsize='8')
plt.text(8 ,-8.5, 'SOURCE: IMDb', color='grey', fontsize='8')
plt.text(-1.8,-6, '___________________________________________________________________________', color='grey')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-c753a94d8788> in <module>()
#       9 ax.set_xticklabels(range(1,11), rotation=0, color='#BCBCBC')
#      10 ax.set_yticklabels(range(0,60,10), color='#BCBCBC')
# ---> 11 ax.set_yticks([range(0,40,10), '%40'])
#      12 plt.xlabel('Rating',fontsize=10, fontweight='bold', color='black')
#      13 plt.ylabel('Percent of total votes',fontsize=10, fontweight='bold', color='black')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in set_yticks(self, ticks, minor)
#    3724             Default is ``False``.
#    3725         """
# -> 3726         ret = self.yaxis.set_ticks(ticks, minor=minor)
#    3727         return ret
#    3728
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1706             xleft, xright = self.get_view_interval()
# ...

# %%
#import the data
candy_url='https://github.com/fivethirtyeight/data/raw/master/candy-power-ranking/candy-data.csv'
candyDF=pd.read_csv(candy_url)
#eliminate the columns we don't need
candyCol=candyDF.columns.to_list()
candyCol=(candyCol[1:-1])
candyDF=candyDF.drop(candyCol, axis=1)
#sort the data so its in the right order
candyDF=candyDF.sort_values(by='winpercent', ascending=True)

# %%
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
fig=plt.figure(figsize=[6.4,50])
ax=fig.add_subplot(111)
ax.barh(candyDF['competitorname'],candyDF['winpercent'], height=.81)
plt.grid(True)
#ax.grid(which='minor', color='black')
ax.tick_params(which='minor')
ax.yaxis.set_minor_locator(MultipleLocator(.5))

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
#
# ### 3) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
# More Work Here
