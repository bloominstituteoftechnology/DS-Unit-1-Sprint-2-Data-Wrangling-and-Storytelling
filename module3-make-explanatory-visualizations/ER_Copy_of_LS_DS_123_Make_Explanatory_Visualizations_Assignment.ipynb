# %% [markdown]
# <a href="https://colab.research.google.com/github/ericriveraisme/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module3-make-explanatory-visualizations/ER_Copy_of_LS_DS_123_Make_Explanatory_Visualizations_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# ### 2) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/) (try the [`altair`](https://altair-viz.github.io/gallery/index.html#maps) library)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/) (try the [`statsmodels`](https://www.statsmodels.org/stable/index.html) library)
# - or another example of your choice!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # 1) Replicate Lesson Code

# %%
# Your Work Here

df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')
df.head()
# Out:
#                     timestamp  respondents  ... 9_pct 10_pct
# 0  2017-07-17 12:28:32.785639          402  ...   5.0   33.6
# 1  2017-07-17 12:28:33.025600           78  ...   3.8   62.8
# 2  2017-07-17 12:28:33.273919            4  ...   0.0   25.0
# 3  2017-07-17 12:28:33.495325            4  ...   0.0   25.0
# 4  2017-07-17 12:28:33.722849          130  ...   4.6   49.2
#
# [5 rows x 27 columns]

# %%
df.dtypes
# Out:
# timestamp       object
# respondents      int64
# category        object
# link            object
# average        float64
# mean           float64
# median           int64
# 1_votes          int64
# 2_votes          int64
# 3_votes          int64
# 4_votes          int64
# 5_votes          int64
# 6_votes          int64
# 7_votes          int64
# 8_votes          int64
# 9_votes          int64
# 10_votes         int64
# 1_pct          float64
# 2_pct          float64
# 3_pct          float64
# 4_pct          float64
# 5_pct          float64
# 6_pct          float64
# 7_pct          float64
# 8_pct          float64
# 9_pct          float64
# 10_pct         float64
# dtype: object

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

df.describe
# Out:
# <bound method NDFrame.describe of                        timestamp  respondents  ... 9_pct 10_pct
# 0     2017-07-17 12:28:32.785639          402  ...   5.0   33.6
# 1     2017-07-17 12:28:33.025600           78  ...   3.8   62.8
# 2     2017-07-17 12:28:33.273919            4  ...   0.0   25.0
# 3     2017-07-17 12:28:33.495325            4  ...   0.0   25.0
# 4     2017-07-17 12:28:33.722849          130  ...   4.6   49.2
# 5     2017-07-17 12:28:33.970009          108  ...   5.6   45.4
# 6     2017-07-17 12:28:34.199847           17  ...   0.0   70.6
# 7     2017-07-17 12:28:34.381001          196  ...   6.1   32.1
# 8     2017-07-17 12:28:34.590224          164  ...   7.3   25.6
# 9     2017-07-17 12:28:34.807101           25  ...   0.0   80.0
# 10    2017-07-17 12:28:35.055251          105  ...   3.8   32.4
# 11    2017-07-17 12:28:35.326192           79  ...   1.3   31.6
# 12    2017-07-17 12:28:35.610367           24  ...  12.5   33.3
# ...

# %%
df.dtypes
# Out:
# timestamp      datetime64[ns]
# respondents             int64
# category               object
# link                   object
# average               float64
# mean                  float64
# median                  int64
# 1_votes                 int64
# 2_votes                 int64
# 3_votes                 int64
# 4_votes                 int64
# 5_votes                 int64
# 6_votes                 int64
# 7_votes                 int64
# 8_votes                 int64
# 9_votes                 int64
# 10_votes                int64
# 1_pct                 float64
# 2_pct                 float64
# 3_pct                 float64
# 4_pct                 float64
# 5_pct                 float64
# 6_pct                 float64
# 7_pct                 float64
# 8_pct                 float64
# 9_pct                 float64
# 10_pct                float64
# dtype: object

# %%
df['timestamp'].min()
# Out:
# Timestamp('2017-07-17 12:28:32.785639')

# %%
df['timestamp'].max()
# Out:
# Timestamp('2017-08-29 23:10:06.218251')

# %%
df = df.set_index('timestamp')

df.head()
# Out:
#                             respondents        category  ... 9_pct  10_pct
# timestamp                                                ...
# 2017-07-17 12:28:32.785639          402           Males  ...   5.0    33.6
# 2017-07-17 12:28:33.025600           78         Females  ...   3.8    62.8
# 2017-07-17 12:28:33.273919            4   Aged under 18  ...   0.0    25.0
# 2017-07-17 12:28:33.495325            4  Males under 18  ...   0.0    25.0
# 2017-07-17 12:28:33.722849          130      Aged 18-29  ...   4.6    49.2
#
# [5 rows x 26 columns]

# %%
df['2017-08-29']
# Out:
#                             respondents            category  ... 9_pct  10_pct
# timestamp                                                    ...
# 2017-08-29 00:00:02.248882         1682               Males  ...   4.9    30.9
# 2017-08-29 00:00:02.499363          257             Females  ...  10.1    51.0
# 2017-08-29 00:00:02.727204           15       Aged under 18  ...   0.0    40.0
# 2017-08-29 00:00:03.024270           13      Males under 18  ...   0.0    46.2
# 2017-08-29 00:00:03.248207            2    Females under 18  ...   0.0     0.0
# 2017-08-29 00:00:03.441529          450          Aged 18-29  ...   5.1    42.2
# 2017-08-29 00:00:03.636825          402    Males Aged 18-29  ...   5.2    40.5
# 2017-08-29 00:00:03.839446           41  Females Aged 18-29  ...   4.9    56.1
# 2017-08-29 00:00:04.030663          771          Aged 30-44  ...   6.4    32.4
# 2017-08-29 00:00:04.225962          679    Males Aged 30-44  ...   5.7    29.5
# ...

# %%
lastday = df['2017-08-29']
lastday_filtered = lastday[lastday['category'] == 'IMDb users']

lastday_filtered.head()
# Out:
#                             respondents    category  ... 9_pct  10_pct
# timestamp                                            ...
# 2017-08-29 00:00:06.288486         2646  IMDb users  ...   5.4    33.7
# 2017-08-29 00:10:06.763461         2646  IMDb users  ...   5.4    33.7
# 2017-08-29 00:20:05.745307         2646  IMDb users  ...   5.4    33.7
# 2017-08-29 00:30:05.818552         2646  IMDb users  ...   5.4    33.7
# 2017-08-29 00:40:06.180928         2646  IMDb users  ...   5.4    33.7
#
# [5 rows x 26 columns]

# %%
lastday_filtered.tail()
# Out:
#                             respondents    category  ... 9_pct  10_pct
# timestamp                                            ...
# 2017-08-29 22:30:06.423181         2662  IMDb users  ...   5.5    33.7
# 2017-08-29 22:40:06.233659         2662  IMDb users  ...   5.5    33.7
# 2017-08-29 22:50:06.592571         2662  IMDb users  ...   5.5    33.7
# 2017-08-29 23:00:05.829558         2662  IMDb users  ...   5.5    33.7
# 2017-08-29 23:10:06.218251         2662  IMDb users  ...   5.5    33.7
#
# [5 rows x 26 columns]

# %%
lastday_filtered['respondents'].plot()

# %%
lastday_filtered['category'].value_counts()
# Out:
# IMDb users    140
# Name: category, dtype: int64

# %%
pct_columns = [f'{i}_pct' for i in range(1, 11)]

pct_columns
# Out:
# ['1_pct',
#  '2_pct',
#  '3_pct',
#  '4_pct',
#  '5_pct',
#  '6_pct',
#  '7_pct',
#  '8_pct',
#  '9_pct',
#  '10_pct']

# %%
final = lastday_filtered.tail(1)

final
# Out:
#                             respondents    category  ... 9_pct  10_pct
# timestamp                                            ...
# 2017-08-29 23:10:06.218251         2662  IMDb users  ...   5.5    33.7
#
# [1 rows x 26 columns]

# %%
final[pct_columns].T
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1_pct                            38.4
# 2_pct                             2.6
# 3_pct                             1.4
# 4_pct                             0.9
# 5_pct                             2.1
# 6_pct                             4.1
# 7_pct                             5.8
# 8_pct                             5.5
# 9_pct                             5.5
# 10_pct                           33.7

# %%
plot_data = final[pct_columns].T

plot_data.index = range(1, 11)

# %%
plot_data
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1                                38.4
# 2                                 2.6
# 3                                 1.4
# 4                                 0.9
# 5                                 2.1
# 6                                 4.1
# 7                                 5.8
# 8                                 5.5
# 9                                 5.5
# 10                               33.7

# %%
plt.style.use('fivethirtyeight')

ax= plot_data.plot.bar(color='#ed713a', width=0.9)

plt.xlabel('Rating', fontsize=10, fontweight='bold')
plt.ylabel('Percent of total votes', fontsize=10, fontweight='bold')
plt.title('`An Inconvenient Sequel: Truth to Power` is divisive',
          fontsize=12,
          x=-0.1, y=1.1, loc='left',
          fontweight='bold')
plt.text(x=-1.8, y=plot_data.max() + 4, s='IMDb ratings for the film as of Aug. 29')
plt.xticks(rotation=0, color='#a7a7a7')
plt.yticks(range(0,50,10), labels=[f'{i}' if i!=40 else f'{i}%' for i in range(0,50,10)], color='#a7a7a7');
legend = ax.legend()
legend.remove()

# %% [markdown]
# # 2) Seaborn Example

# %%
sdf = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/thanksgiving-2015/thanksgiving-2015-poll-data.csv')

sdf.head()
# Out:
#    RespondentID  ...           US Region
# 0    4337954960  ...     Middle Atlantic
# 1    4337951949  ...  East South Central
# 2    4337935621  ...            Mountain
# 3    4337933040  ...             Pacific
# 4    4337931983  ...             Pacific
#
# [5 rows x 65 columns]

# %%
sdf.dtypes
# Out:
# RespondentID                                                                                                                                     int64
# Do you celebrate Thanksgiving?                                                                                                                  object
# What is typically the main dish at your Thanksgiving dinner?                                                                                    object
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)                                                           object
# How is the main dish typically cooked?                                                                                                          object
# How is the main dish typically cooked? - Other (please specify)                                                                                 object
# ...

# %%
sdf['Age'].dtypes
# Out:
# dtype('O')

# %%
sdf['Age'].head()
# Out:
# 0    18 - 29
# 1    18 - 29
# 2    18 - 29
# 3    30 - 44
# 4    30 - 44
# Name: Age, dtype: object

# %%
sdf['Age'] = pd.to_numeric(sdf['Age'], errors='ignore')     #astype(int(x='18-29', base=18)) #.value_counts()#astype(object).astype(int(x=18))

# %%
sdf.Age.astype(str).head()
# Out:
# 0    18 - 29
# 1    18 - 29
# 2    18 - 29
# 3    30 - 44
# 4    30 - 44
# Name: Age, dtype: object

# %%
sdf['Age'].isna().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
sdf['Age'].dropna().head()
# Out:
# 0    18 - 29
# 1    18 - 29
# 2    18 - 29
# 3    30 - 44
# 4    30 - 44
# Name: Age, dtype: object

# %%
sdf.Age.astype(int(errors='ignore')).head()

# %%
age_bins = pd.cut(sdf['Age'],4)  # 5 equal-sized bins

#age_bins

# %%
sdf = pd.to_numeric(sdf)
sdf.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ae81ac0b6f5e> in <module>()
# ----> 1 sdf = pd.to_numeric(sdf)
#       2 sdf.dtypes
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     120         values = np.array([arg], dtype='O')
#     121     elif getattr(arg, 'ndim', 1) > 1:
# --> 122         raise TypeError('arg must be a list, tuple, 1-d array, or Series')
#     123     else:
#     124         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
sdf.plot('Age', 'How much total combined money did all members of your HOUSEHOLD earn last year?', kind='bar')

# %%
sdf.describe
# Out:
# <bound method NDFrame.describe of       RespondentID  ...           US Region
# 0       4337954960  ...     Middle Atlantic
# 1       4337951949  ...  East South Central
# 2       4337935621  ...            Mountain
# 3       4337933040  ...             Pacific
# 4       4337931983  ...             Pacific
# 5       4337929779  ...             Pacific
# 6       4337924420  ...  East North Central
# 7       4337916002  ...            Mountain
# 8       4337914977  ...     Middle Atlantic
# 9       4337899817  ...  East South Central
# 10      4337899680  ...            Mountain
# 11      4337893416  ...     Middle Atlantic
# 12      4337888291  ...  East North Central
# 13      4337878450  ...     Middle Atlantic
# 14      4337878351  ...  West North Central
# 15      4337857295  ...             Pacific
# 16      4337856362  ...             Pacific
# 17      4337854106  ...  East North Central
# 18      4337844879  ...            Mountain
# 19      4337823612  ...  East North Central
# ...

# %%
hunch = sdf.iloc[:, lambda df: [61, 63]]

hunch.dtypes
# Out:
# Age                                                                                object
# How much total combined money did all members of your HOUSEHOLD earn last year?    object
# dtype: object

# %%
hunch.astype(dtype=int)

# Ultimate Frustration! Rage Quit...
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-894e50a77af8> in <module>()
# ----> 1 hunch.astype(dtype=int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

alt.Chart(source).mark_circle(size=60).encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()

# %%
import altair as alt
#from vega_datasets import data



source = sdf

alt.Chart(source).mark_circle(size=60).encode(
    x='How would you describe where you live?',
    y='Age',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()

# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()
brush = alt.selection(type='interval', encodings=['x'])

bars = alt.Chart().mark_bar().encode(
    x='month(date):O',
    y='mean(precipitation):Q',
    opacity=alt.condition(brush, alt.OpacityValue(1), alt.OpacityValue(0.7)),
).add_selection(
    brush
)

line = alt.Chart().mark_rule(color='firebrick').encode(
    y='mean(precipitation):Q',
    size=alt.SizeValue(3)
).transform_filter(
    brush
)

alt.layer(bars, line, data=source)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
#
# ### 3) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
# More Work Here
