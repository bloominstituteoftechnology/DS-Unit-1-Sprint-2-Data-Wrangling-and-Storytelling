# %% [markdown]
# <a href="https://colab.research.google.com/github/SarmenSinanian/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/Sarmen_Sinanian_123_Make_Explanatory_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT
#
# Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# # STRETCH OPTIONS
#
# #### Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# For example:
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/) (try the [`altair`](https://altair-viz.github.io/gallery/index.html#maps) library)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/) (try the [`statsmodels`](https://www.statsmodels.org/stable/index.html) library)
# - or another example of your choice!
#
# #### Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,aspect=1)

def minor_tick(x,pos):
  if not x % 1.0:
    return ""
  return "%.2f" % x

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter(FuncFormatter(minor_tick))

ax.set_xlim(0,4)
ax.set_ylim(0,4)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', width=1.0, labelsize=10)
ax.tick_params(which='minor', length=5, labelsize=10, labelcolor='0.25')

ax.grid(linestyle="--",linewidth=0.5,color='.25',zorder=-10)

ax.plot(X,Y1,c=(0.25,0.25,1.00),lw=2,label="Blue signal",zorder=10)
ax.plot(X,Y2,c=(1.00,0.25,0.25),lw=2,label="red signal")
ax.plot(X,Y3,linewidth=0,marker='o',markerfacecolor='w',markeredgecolor='k')

ax.set_title("Anatomy of a figure", fontsize=20,verticalalignment='bottom')
ax.set_xlabel("X axis label")
ax.set_ylabel("Y Axis label")

ax.legend()

def circle(x, y, radius=0.15):
    from matplotlib.patches import Circle
    from matplotlib.patheffects import withStroke
    circle = Circle((x, y), radius, clip_on=False, zorder=10, linewidth=1,
                    edgecolor='black', facecolor=(0,0,0,.0125),
                    path_effects=[withStroke(linewidth=5, foreground='w')])
    ax.add_artist(circle)

def text(x,y,text):
  ax.text(x,y,text,backgroundcolor="white",
         ha='center',va='top',weight='bold',color='blue')
  
#Minor tick
circle(0.50,-0.10)
text(0.50,-0.32,"minor tick label")

#Major tick
circle(-0.03,4.00)
text(0.03,3.80,"Major tick")

#Minor tick
circle(0.00,3.50)
text(0.00,3.30,"Minor tick")

#Major tick label
circle(-0.15, 3.00)
text(-0.15,2.80,"Major tick label")

#X label
circle(1.8,-.27)
text(1.8,-.45,"X axis label")

#Y label
circle(-.27, 1.8)
text(-.27, 1.6, "Y axis label")

#Title
circle(1.6, 4.13)
text(1.6,3.93,"Title")

#Blue plot
circle(1.75,2.8)
text(1.75, 2.6, "Line \n(line plot)")

#Red plot
circle(1.2, .6)
text(1.2, .4, "Line\n(line plot)")

#Scatter plot
circle(3.2,1.75)
text(3.2, 1.55, "Markers\n(scatter plot)")

#Grid
circle(3.0,3.0)
text(3.0,2.8,"Grid")

#Legend
circle(3.7,3.8)
text(3.7,3.6,"Legend")

#Axes
circle(.5,.5)
text(.5,.3,"Axes")

#Figure
circle(-.3,.65)
text(-.3,.45,"Figure")

color = 'blue'
ax.annotate('Spines', xy=(4,.35), xytext=(3.3,.5),
            weight='bold', color=color,
            arrowprops=dict(arrowstyle='->',
                           connectionstyle="arc3",
                           color=color))

ax.annotate('',xy=(3.15,0),xytext=(3.45,0.45),
            weight='bold',color=color,
            arrowprops=dict(arrowstyle='->',
                           connectionstyle="arc3",
                           color=color))

ax.text(4,-.4,"Made with http://matplotlib.org",
       fontsize=10,ha="right",color='.5')

plt.show()

# %%
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('fivethirtyeight')

fake=pd.Series([38,3,2,1,2,4,6,5,5,33],
              index=range(1,11))

fake.plot.bar(color="#f2883d", width=.9);

# %%
display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
plt.style.use('fivethirtyeight')

fig=plt.figure()

#set figure background color
fig.patch.set_facecolor('white')

#set bar color and width
# ax=fake.plot.bar(color='#f2883d',width=.9)

#set inner AXES color
ax.set(facecolor='white')

#set title and subtitle
ax.text(x=-2,y=46, s="'An Inconvenient Seuqle: Truth to Power' is divise", fontweight="bold",fontsize='12')
ax.text(x=-2,y=43,s="IMDB ratings for the film as of Aug. 29", fontsize=12);

#set x and y-axis ticks
ax.set_xticklabels(range(1,11),rotation=0)
ax.set_yticks(range(0,50,10))
ax.set_yticklabels(range(0,50,10))

#set axis labels
plt.ylabel(ylabel='Percent of total votes', fontsize=0,fontweight='bold',labelpad=15)
plt.xlabel(xlabel='Rating',fontsize=9,fontweight='bold',labelpad=15)

plt.show()

# %%
df= pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/inconvenient-sequel/ratings.csv')

# %%
pd.set_option('display.max_columns',50)
print(df.shape)
df.head(20)
# Out:
# (80053, 27)
#                      timestamp  respondents            category  \
# 0   2017-07-17 12:28:32.785639          402               Males
# 1   2017-07-17 12:28:33.025600           78             Females
# 2   2017-07-17 12:28:33.273919            4       Aged under 18
# 3   2017-07-17 12:28:33.495325            4      Males under 18
# 4   2017-07-17 12:28:33.722849          130          Aged 18-29
# 5   2017-07-17 12:28:33.970009          108    Males Aged 18-29
# 6   2017-07-17 12:28:34.199847           17  Females Aged 18-29
# 7   2017-07-17 12:28:34.381001          196          Aged 30-44
# 8   2017-07-17 12:28:34.590224          164    Males Aged 30-44
# 9   2017-07-17 12:28:34.807101           25  Females Aged 30-44
# 10  2017-07-17 12:28:35.055251          105            Aged 45+
# 11  2017-07-17 12:28:35.326192           79      Males Aged 45+
# 12  2017-07-17 12:28:35.610367           24    Females Aged 45+
# ...

# %%
df.sample(1).T
# Out:
#                                                          29977
# timestamp                           2017-08-11 15:50:04.489361
# respondents                                                591
# category                                            Aged 30-44
# link         http://www.imdb.com/title/tt6322922/ratings-age_3
# average                                                    5.3
# mean                                                       5.5
# median                                                       6
# 1_votes                                                    243
# 2_votes                                                     20
# 3_votes                                                      8
# 4_votes                                                      3
# 5_votes                                                     11
# 6_votes                                                     16
# 7_votes                                                     23
# ...

# %%
df.tail()
# Out:
#                         timestamp  respondents         category  \
# 80048  2017-08-29 23:10:05.369510            8       IMDb staff
# 80049  2017-08-29 23:10:05.598331           41  Top 1000 voters
# 80050  2017-08-29 23:10:05.794141          925         US users
# 80051  2017-08-29 23:10:06.022268          565     Non-US users
# 80052  2017-08-29 23:10:06.218251         2662       IMDb users
#
#                                                     link  average  mean  \
# 80048  http://www.imdb.com/title/tt6322922/ratings-im...      8.4   7.2
# 80049  http://www.imdb.com/title/tt6322922/ratings-to...      4.6   4.7
# 80050    http://www.imdb.com/title/tt6322922/ratings-usa      4.8   5.0
# 80051  http://www.imdb.com/title/tt6322922/ratings-in...      6.4   6.5
# 80052        http://www.imdb.com/title/tt6322922/ratings      5.4   5.6
#
#        median  1_votes  2_votes  3_votes  4_votes  5_votes  6_votes  7_votes  \
# ...

# %%
df.dtypes
# Out:
# timestamp       object
# respondents      int64
# category        object
# link            object
# average        float64
# mean           float64
# median           int64
# 1_votes          int64
# 2_votes          int64
# 3_votes          int64
# 4_votes          int64
# 5_votes          int64
# 6_votes          int64
# 7_votes          int64
# 8_votes          int64
# 9_votes          int64
# 10_votes         int64
# 1_pct          float64
# 2_pct          float64
# 3_pct          float64
# 4_pct          float64
# 5_pct          float64
# 6_pct          float64
# 7_pct          float64
# 8_pct          float64
# 9_pct          float64
# 10_pct         float64
# dtype: object

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])
df['timestamp'].describe()
# Out:
# count                          80053
# unique                         80053
# top       2017-07-24 23:00:02.760781
# freq                               1
# first     2017-07-17 12:28:32.785639
# last      2017-08-29 23:10:06.218251
# Name: timestamp, dtype: object

# %%
df.dtypes
# Out:
# timestamp      datetime64[ns]
# respondents             int64
# category               object
# link                   object
# average               float64
# mean                  float64
# median                  int64
# 1_votes                 int64
# 2_votes                 int64
# 3_votes                 int64
# 4_votes                 int64
# 5_votes                 int64
# 6_votes                 int64
# 7_votes                 int64
# 8_votes                 int64
# 9_votes                 int64
# 10_votes                int64
# 1_pct                 float64
# 2_pct                 float64
# 3_pct                 float64
# 4_pct                 float64
# 5_pct                 float64
# 6_pct                 float64
# 7_pct                 float64
# 8_pct                 float64
# 9_pct                 float64
# 10_pct                float64
# dtype: object

# %%
df.set_index('timestamp',inplace=True)
df['2017-08-29']
# Out:
#                             respondents            category  \
# timestamp
# 2017-08-29 00:00:02.248882         1682               Males
# 2017-08-29 00:00:02.499363          257             Females
# 2017-08-29 00:00:02.727204           15       Aged under 18
# 2017-08-29 00:00:03.024270           13      Males under 18
# 2017-08-29 00:00:03.248207            2    Females under 18
# 2017-08-29 00:00:03.441529          450          Aged 18-29
# 2017-08-29 00:00:03.636825          402    Males Aged 18-29
# 2017-08-29 00:00:03.839446           41  Females Aged 18-29
# 2017-08-29 00:00:04.030663          771          Aged 30-44
# 2017-08-29 00:00:04.225962          679    Males Aged 30-44
# 2017-08-29 00:00:04.539312           76  Females Aged 30-44
# 2017-08-29 00:00:04.776104          539            Aged 45+
# 2017-08-29 00:00:04.973766          421      Males Aged 45+
# 2017-08-29 00:00:05.176998          109    Females Aged 45+
# ...

# %%
lastday = df['2017-08-29']
lastday_filtered = lastday[lastday['category'] == 'IMDb users']
lastday_filtered.tail(30)
# Out:
#                             respondents    category  \
# timestamp
# 2017-08-29 18:20:06.215486         2654  IMDb users
# 2017-08-29 18:30:06.738669         2654  IMDb users
# 2017-08-29 18:40:05.771150         2654  IMDb users
# 2017-08-29 18:50:06.051326         2654  IMDb users
# 2017-08-29 19:00:06.002542         2654  IMDb users
# 2017-08-29 19:10:06.066863         2654  IMDb users
# 2017-08-29 19:20:06.286871         2654  IMDb users
# 2017-08-29 19:30:06.395003         2654  IMDb users
# 2017-08-29 19:40:06.372808         2654  IMDb users
# 2017-08-29 19:50:06.030788         2654  IMDb users
# 2017-08-29 20:00:06.213617         2660  IMDb users
# 2017-08-29 20:10:06.353175         2660  IMDb users
# 2017-08-29 20:20:06.692848         2660  IMDb users
# 2017-08-29 20:30:06.047404         2660  IMDb users
# 2017-08-29 20:40:06.341599         2660  IMDb users
# 2017-08-29 20:50:06.265539         2660  IMDb users
# 2017-08-29 21:00:07.056294         2660  IMDb users
# ...

# %%
df['category'].value_counts()
# Out:
# Aged 30-44            4216
# Aged 18-29            4216
# Top 1000 voters       4216
# Males Aged 30-44      4216
# Females Aged 30-44    4216
# Non-US users          4216
# Females Aged 45+      4216
# Females Aged 18-29    4216
# Males                 4216
# Males under 18        4216
# US users              4216
# Females               4216
# Males Aged 45+        4216
# IMDb staff            4216
# Aged 45+              4216
# Aged under 18         4216
# Males Aged 18-29      4216
# IMDb users            4216
# Females under 18      4165
# Name: category, dtype: int64

# %%
lastday_filtered.respondents.plot();

# %%
final = lastday_filtered.tail(1)
final.T
# Out:
# timestamp                     2017-08-29 23:10:06.218251
# respondents                                         2662
# category                                      IMDb users
# link         http://www.imdb.com/title/tt6322922/ratings
# average                                              5.4
# mean                                                 5.6
# median                                                 7
# 1_votes                                             1021
# 2_votes                                               69
# 3_votes                                               38
# 4_votes                                               25
# 5_votes                                               55
# 6_votes                                              110
# 7_votes                                              154
# 8_votes                                              147
# 9_votes                                              146
# ...

# %%
pct_columns = ['1_pct', '2_pct', '3_pct', '4_pct', '5_pct',
               '6_pct', '7_pct', '8_pct', '9_pct', '10_pct']

final[pct_columns].T
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1_pct                            38.4
# 2_pct                             2.6
# 3_pct                             1.4
# 4_pct                             0.9
# 5_pct                             2.1
# 6_pct                             4.1
# 7_pct                             5.8
# 8_pct                             5.5
# 9_pct                             5.5
# 10_pct                           33.7

# %%
plot_data = final[pct_columns].T
plot_data.index = range(1,11)
plot_data
# Out:
# timestamp  2017-08-29 23:10:06.218251
# 1                                38.4
# 2                                 2.6
# 3                                 1.4
# 4                                 0.9
# 5                                 2.1
# 6                                 4.1
# 7                                 5.8
# 8                                 5.5
# 9                                 5.5
# 10                               33.7

# %%
plt.style.use('fivethirtyeight')

fig = plt.figure()

# set figure background color
fig.patch.set_facecolor('white')

# set bar color and width
ax = plot_data.plot.bar(color='#ED713A', width=0.9)

# set inner Axes color
ax.set(facecolor='white')

# ax.set_title("Is this the title?")

# Set title and subtitle
ax.text(x=-2, y=46, s="'An Inconvenient Sequel: Truth To Power' is divisive", fontweight="bold", fontsize='12')
ax.text(x=-2, y=43, s="IMDB ratings for the film as of Aug. 29", fontsize=12);

# Set x and y-axis ticks
ax.set_xticklabels(range(1,11), rotation=0)
ax.set_yticks(range(0,50,10))
ax.set_yticklabels(range(0,50,10))

# Set axis labels
plt.ylabel(ylabel='Percent of total votes', fontsize=9, fontweight='bold', labelpad=15)
plt.xlabel(xlabel='Rating', fontsize=9, fontweight='bold', labelpad=15)

plt.show();

# %% [markdown]
# #1ST STRETCH GOAL ATEMPTED BEGINS HERE!!!!!!!

# %%
df1 = pd.read_csv('https://projects.fivethirtyeight.com/polls-page/president_approval_polls.csv')
#Presidential approval polls

# %%
df1.head(50)
#Czeching first 50 values
# Out:
#     question_id  poll_id   cycle  state    politician  pollster_id  \
# 0         99471    58688  2020.0    NaN  Donald Trump         1416
# 1         99466    58685  2020.0    NaN  Donald Trump          568
# 2         99467    58685  2020.0    NaN  Donald Trump          568
# 3         99469    58686  2019.0    NaN  Donald Trump          399
# 4         99464    58683  2020.0    NaN  Donald Trump         1416
# 5         99370    58674  2020.0    NaN  Donald Trump          744
# 6         99457    58674  2020.0    NaN  Donald Trump          744
# 7         99371    58675  2020.0    NaN  Donald Trump          568
# 8         99372    58675  2020.0    NaN  Donald Trump          568
# 9         99375    58677  2020.0    NaN  Donald Trump          568
# 10        99376    58677  2020.0    NaN  Donald Trump          568
# 11        99381    58678  2019.0    NaN  Donald Trump          399
# 12        99369    58673  2020.0    NaN  Donald Trump         1416
# ...

# %%
df1.tail()
# Out:
#       question_id  poll_id   cycle  state    politician  pollster_id  \
# 5625        77560    49426  2017.0    NaN  Donald Trump          744
# 5626        77599    49426  2017.0    NaN  Donald Trump          744
# 5627        77274    49262  2017.0    NaN  Donald Trump          169
# 5628        77261    49249  2017.0    NaN  Donald Trump         1189
# 5629        77265    49253  2017.0    NaN  Donald Trump          169
#
#              pollster sponsor_ids  sponsors     display_name  \
# 5625            Ipsos          71   Reuters            Ipsos
# 5626            Ipsos          71   Reuters            Ipsos
# 5627           Gallup         NaN       NaN           Gallup
# 5628  Morning Consult         538  Politico  Morning Consult
# 5629           Gallup         NaN       NaN           Gallup
#
#       pollster_rating_id pollster_rating_name fte_grade  sample_size  \
# 5625               154.0                Ipsos        B+          509
# ...

# %%
df1.shape
#Czeching rowsXcolumns
# Out:
# (5630, 27)

# %%
df1.sample(1).T
#Czeching columns via a random sample transposed for ease of visibility
# Out:
#                                                                    4245
# question_id                                                       78881
# poll_id                                                           50196
# cycle                                                              2017
# state                                                               NaN
# politician                                                 Donald Trump
# pollster_id                                                         744
# pollster                                                          Ipsos
# sponsor_ids                                                          71
# sponsors                                                        Reuters
# display_name                                                      Ipsos
# pollster_rating_id                                                  154
# pollster_rating_name                                              Ipsos
# ...

# %%
df1.dtypes
#Czeching data types. Interested in "created_at" for recent polls
# Out:
# question_id               int64
# poll_id                   int64
# cycle                   float64
# state                   float64
# politician               object
# pollster_id               int64
# pollster                 object
# sponsor_ids              object
# sponsors                 object
# display_name             object
# pollster_rating_id      float64
# pollster_rating_name     object
# fte_grade                object
# sample_size               int64
# population               object
# population_full          object
# methodology              object
# start_date               object
# end_date                 object
# sponsor_candidate       float64
# tracking                 object
# created_at               object
# notes                    object
# url                      object
# source                   object
# yes                     float64
# no                      float64
# dtype: object

# %%
df1.describe()
#No help
# Out:
#         question_id       poll_id        cycle  state  pollster_id  \
# count   5630.000000   5630.000000  5449.000000    0.0  5630.000000
# mean   85679.097158  53525.451865  2017.708203    NaN   711.014565
# std     6782.473677   3358.051825    27.361325    NaN   344.681490
# min    77244.000000  49232.000000     0.000000    NaN    11.000000
# 25%    78957.250000  50236.250000  2017.000000    NaN   568.000000
# 50%    83394.500000  52671.500000  2018.000000    NaN   744.000000
# 75%    92472.750000  57190.750000  2019.000000    NaN   744.000000
# max    99471.000000  58688.000000  2020.000000    NaN  1486.000000
#
#        pollster_rating_id   sample_size  sponsor_candidate          yes  \
# count         5616.000000   5630.000000                0.0  5630.000000
# mean           230.295228   2059.670160                NaN    42.416542
# std            105.402995   2703.210907                NaN     3.666909
# min              3.000000    121.000000                NaN    23.900000
# ...

# %%
df1['created_at']=pd.to_datetime(df1['created_at'])
df1['created_at'].describe()
#Transforming "created_at" data in(to)_datetime format *lol* 
#Followed up by describing the first/last values
# Out:
# count                    5630
# unique                   2650
# top       2017-03-01 17:53:00
# freq                      101
# first     2017-02-06 17:40:00
# last      2019-07-18 18:44:00
# Name: created_at, dtype: object

# %%
df1['created_at'].head(10)
#Czeching for consistency
# Out:
# 0   2019-07-18 18:44:00
# 1   2019-07-18 09:11:00
# 2   2019-07-18 09:11:00
# 3   2019-07-18 09:42:00
# 4   2019-07-17 17:02:00
# 5   2019-07-16 20:24:00
# 6   2019-07-17 11:20:00
# 7   2019-07-16 20:24:00
# 8   2019-07-16 20:24:00
# 9   2019-07-17 09:48:00
# Name: created_at, dtype: datetime64[ns]

# %%
df1['created_at'].sort_values(ascending=False)
#Sorting values
# Out:
# 0      2019-07-18 18:44:00
# 3      2019-07-18 09:42:00
# 1      2019-07-18 09:11:00
# 2      2019-07-18 09:11:00
# 30     2019-07-18 09:10:00
# 4      2019-07-17 17:02:00
# 6      2019-07-17 11:20:00
# 11     2019-07-17 09:52:00
# 9      2019-07-17 09:48:00
# 10     2019-07-17 09:48:00
# 8      2019-07-16 20:24:00
# 7      2019-07-16 20:24:00
# 5      2019-07-16 20:24:00
# 12     2019-07-16 19:03:00
# 27     2019-07-16 16:54:00
# 19     2019-07-16 16:54:00
# 24     2019-07-16 10:59:00
# 20     2019-07-16 10:59:00
# 16     2019-07-16 09:33:00
# 13     2019-07-16 09:10:00
# 14     2019-07-16 09:10:00
# 15     2019-07-15 17:16:00
# 21     2019-07-15 09:34:00
# 18     2019-07-15 09:22:00
# 17     2019-07-15 09:22:00
# 39     2019-07-15 09:22:00
# 23     2019-07-14 10:01:00
# 22     2019-07-14 10:01:00
# 49     2019-07-14 10:01:00
# 25     2019-07-13 10:08:00
#                ...
# 5582   2017-02-06 17:50:00
# 5627   2017-02-06 17:48:00
# 5548   2017-02-06 17:48:00
# ...

# %%
# df1.set_index('created_at',inplace=True)

# %%
df1[df1['pollster']=='YouGov']
#Sorting via pollster column for YouGov values (highest rated pollster of recent polling data in this set)
# Out:
#       question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 1           99466    58685  2020.0    NaN  Donald Trump          568   YouGov
# 2           99467    58685  2020.0    NaN  Donald Trump          568   YouGov
# 7           99371    58675  2020.0    NaN  Donald Trump          568   YouGov
# 8           99372    58675  2020.0    NaN  Donald Trump          568   YouGov
# 9           99375    58677  2020.0    NaN  Donald Trump          568   YouGov
# 10          99376    58677  2020.0    NaN  Donald Trump          568   YouGov
# 13          99329    58665  2020.0    NaN  Donald Trump          568   YouGov
# 14          99330    58665  2020.0    NaN  Donald Trump          568   YouGov
# 17          99311    58657  2020.0    NaN  Donald Trump          568   YouGov
# 18          99312    58657  2020.0    NaN  Donald Trump          568   YouGov
# 22          99305    58656  2020.0    NaN  Donald Trump          568   YouGov
# ...

# %%
you_gov_df = df1[df1['pollster']=='YouGov']
#Filtering and setting dataframe with only YouGov values under column pollster

# %%
you_gov_df.head(20)
#Czeching values for accuracy
# Out:
#     question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 1         99466    58685  2020.0    NaN  Donald Trump          568   YouGov
# 2         99467    58685  2020.0    NaN  Donald Trump          568   YouGov
# 7         99371    58675  2020.0    NaN  Donald Trump          568   YouGov
# 8         99372    58675  2020.0    NaN  Donald Trump          568   YouGov
# 9         99375    58677  2020.0    NaN  Donald Trump          568   YouGov
# 10        99376    58677  2020.0    NaN  Donald Trump          568   YouGov
# 13        99329    58665  2020.0    NaN  Donald Trump          568   YouGov
# 14        99330    58665  2020.0    NaN  Donald Trump          568   YouGov
# 17        99311    58657  2020.0    NaN  Donald Trump          568   YouGov
# 18        99312    58657  2020.0    NaN  Donald Trump          568   YouGov
# 22        99305    58656  2020.0    NaN  Donald Trump          568   YouGov
# ...

# %%
start_date = '2019-07-12'
end_date = '2019-07-19'
#Creating date filtration conditions

# %%
selected_dates = ((you_gov_df['created_at'] > start_date) & (you_gov_df['created_at'] <= end_date))
#Filtering values to be set between a 1 week interval

# %%
selected_dates.head(20)
#Values that match the conditions are labeled true
# Out:
# 1      True
# 2      True
# 7      True
# 8      True
# 9      True
# 10     True
# 13     True
# 14     True
# 17     True
# 18     True
# 22     True
# 23     True
# 25     True
# 26     True
# 31     True
# 32     True
# 35    False
# 36    False
# 44    False
# 45    False
# Name: created_at, dtype: bool

# %%
selected_dates_df = you_gov_df[selected_dates]
#New filtered dataset created with selected dates(1 week) out of the YouGov pollster data

# %%
selected_dates_df.head(20)
#Czeching values
# Out:
#     question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 1         99466    58685  2020.0    NaN  Donald Trump          568   YouGov
# 2         99467    58685  2020.0    NaN  Donald Trump          568   YouGov
# 7         99371    58675  2020.0    NaN  Donald Trump          568   YouGov
# 8         99372    58675  2020.0    NaN  Donald Trump          568   YouGov
# 9         99375    58677  2020.0    NaN  Donald Trump          568   YouGov
# 10        99376    58677  2020.0    NaN  Donald Trump          568   YouGov
# 13        99329    58665  2020.0    NaN  Donald Trump          568   YouGov
# 14        99330    58665  2020.0    NaN  Donald Trump          568   YouGov
# 17        99311    58657  2020.0    NaN  Donald Trump          568   YouGov
# 18        99312    58657  2020.0    NaN  Donald Trump          568   YouGov
# 22        99305    58656  2020.0    NaN  Donald Trump          568   YouGov
# ...

# %%
selected_population_df = selected_dates_df[selected_dates_df['population'] == "rv"]
#Filtering selected_dates_df's population column to contain only the population values of "rv" (polls are seemingly redundant;
# these values come closer to 100% approval/disapproval when added together therefore running on that assumption to 
# say that they are more "complete" polls even though I have no idea which is more representative of the data. Most likely, these
# have a wider/larger confidence interval)

# %%
selected_population_df.head(20)
#Czeching values
# Out:
#     question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 2         99467    58685  2020.0    NaN  Donald Trump          568   YouGov
# 8         99372    58675  2020.0    NaN  Donald Trump          568   YouGov
# 10        99376    58677  2020.0    NaN  Donald Trump          568   YouGov
# 14        99330    58665  2020.0    NaN  Donald Trump          568   YouGov
# 18        99312    58657  2020.0    NaN  Donald Trump          568   YouGov
# 23        99306    58656  2020.0    NaN  Donald Trump          568   YouGov
# 26        99301    58655  2020.0    NaN  Donald Trump          568   YouGov
# 32        99294    58650  2020.0    NaN  Donald Trump          568   YouGov
#
#    sponsor_ids   sponsors display_name  pollster_rating_id  \
# 2          NaN        NaN       YouGov               391.0
# 8          NaN        NaN       YouGov               391.0
# 10         352  Economist       YouGov               391.0
# ...

# %%
selected_population_clean_df = selected_population_df.drop([8],axis=0)
#Dropping row "8" in selected_population_df because it was a second instance of a 07/16/2019 poll. Different values, but dropped regardless

# %%
selected_population_clean_df.head(10)
#Czeching values
# Out:
#     question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 2         99467    58685  2020.0    NaN  Donald Trump          568   YouGov
# 10        99376    58677  2020.0    NaN  Donald Trump          568   YouGov
# 14        99330    58665  2020.0    NaN  Donald Trump          568   YouGov
# 18        99312    58657  2020.0    NaN  Donald Trump          568   YouGov
# 23        99306    58656  2020.0    NaN  Donald Trump          568   YouGov
# 26        99301    58655  2020.0    NaN  Donald Trump          568   YouGov
# 32        99294    58650  2020.0    NaN  Donald Trump          568   YouGov
#
#    sponsor_ids   sponsors display_name  pollster_rating_id  \
# 2          NaN        NaN       YouGov               391.0
# 10         352  Economist       YouGov               391.0
# 14         NaN        NaN       YouGov               391.0
# 18         NaN        NaN       YouGov               391.0
# 23         NaN        NaN       YouGov               391.0
# ...

# %%
selected_population_clean_df.yes.plot()
#Percentage of Yeses (reverse chronological)

# %%
selected_population_clean_df.set_index('created_at', inplace=True)
#Sets index as 'created_at' to have plot properly show chronological progression
# ALONG WITH USING TIMESTAMPS AS X-VALUES INSTEAD OF INDEX NUMBER

# %%
selected_population_clean_df.yes.plot()
#Percentage of Yeses chronological

# %%
selected_population_clean_df_copy = selected_population_clean_df
#Copying selected_population_clean_df

# %%
selected_population_clean_df_copy.head()
#Czeching values
# Out:
#                      question_id  poll_id   cycle  state    politician  \
# created_at
# 2019-07-18 09:11:00        99467    58685  2020.0    NaN  Donald Trump
# 2019-07-17 09:48:00        99376    58677  2020.0    NaN  Donald Trump
# 2019-07-16 09:10:00        99330    58665  2020.0    NaN  Donald Trump
# 2019-07-15 09:22:00        99312    58657  2020.0    NaN  Donald Trump
# 2019-07-14 10:01:00        99306    58656  2020.0    NaN  Donald Trump
#
#                      pollster_id pollster sponsor_ids   sponsors display_name  \
# created_at
# 2019-07-18 09:11:00          568   YouGov         NaN        NaN       YouGov
# 2019-07-17 09:48:00          568   YouGov         352  Economist       YouGov
# 2019-07-16 09:10:00          568   YouGov         NaN        NaN       YouGov
# 2019-07-15 09:22:00          568   YouGov         NaN        NaN       YouGov
# 2019-07-14 10:01:00          568   YouGov         NaN        NaN       YouGov
#
# ...

# %%
selected_population_clean_df_copy_yes = selected_population_clean_df_copy['yes']
#Selecting only yes column

# %%
final_df = selected_population_clean_df_copy_yes.sort_index(axis=0 ,ascending=True)
#Reversing order to present properly/chronologically in graph

# %%
final_df.head()
#Czeching values
# Out:
# created_at
# 2019-07-12 09:47:00    49.0
# 2019-07-13 10:08:00    44.0
# 2019-07-14 10:01:00    45.0
# 2019-07-15 09:22:00    43.0
# 2019-07-16 09:10:00    46.0
# Name: yes, dtype: float64

# %%
# final_df_plot_data = final_df

# %% [markdown]
# #HOW DO YOU CHANGE X AXIS LABELS FROM AUTO LABELING TO STRINGS? OR EVEN CHANGING THE TO_DATE VALUES TO JUST MONTH/DATE VALUES?

# %%
plt.style.use('fivethirtyeight')

fig = plt.figure()

fig.patch.set_facecolor('white')

ax = final_df.plot.bar(color = '#d10000', width = .8, legend = False)

ax.set(facecolor = 'white')

ax.text(x=-2, y=120, s='(P)Resident D.J. Trump Approval Numbers: Crowd Reaction To His Set = "Meh"', fontweight = "bold", fontsize = '12')
ax.text(x=-2, y=110,s="YouGov Poll Results Between 07/13-18/2019", fontsize = 12)

# ax.set_xticklabels(range(1,8),rotation = 0)
# ax.set_xticklabels(rotation = 0)
# ax.set_xticklabels(np.arrange(7), ('07-12', '07-13', '07-14', '07-15', '07-16', '07-17', '07-18'))
ax.set_yticks(range(0,105, 10))
# ax.set_yticklabels(range(0,100,5))

plt.ylabel(ylabel = 'Percent Of Yeses', fontsize = 12, fontweight = 'bold', labelpad = 15)
plt.xlabel(xlabel = 'Dates', fontsize = 12, fontweight = 'bold', labelpad = 15)

plt.show()

# %%
# selected_population_clean_df['created_at'].sort_values(ascending=True)

# %%
# final_df.dtypes()

# %%
# date_values = ['2019-07-12','2019-07-13','2019-07-14','2019-07-15','2019-07-16','2019-07-17','2019-07-18']

# %%
# df1[date_values]

# %%
#  df.dtypes

# %%
# df.set_index('timestamp',inplace=True)
# df['2017-08-29']

# %%
# lastday = df['2017-08-29']
# lastday_filtered = lastday[lastday['category'] == 'IMDb users']
# lastday_filtered.tail(30)

# %%
# df['category'].value_counts()

# %%
# lastday_filtered.respondents.plot();

# %%
# final = lastday_filtered.tail(1)
# final.T

# %%
# pct_columns = ['1_pct', '2_pct', '3_pct', '4_pct', '5_pct',
#                '6_pct', '7_pct', '8_pct', '9_pct', '10_pct']

# final[pct_columns].T

# %%
# plot_data = final[pct_columns].T
# plot_data.index = range(1,11)
# plot_data

# %%
# plt.style.use('fivethirtyeight')

# fig = plt.figure()

# # set figure background color
# fig.patch.set_facecolor('white')

# # set bar color and width
# ax = plot_data.plot.bar(color='#ED713A', width=0.9)

# # set inner Axes color
# ax.set(facecolor='white')

# # ax.set_title("Is this the title?")

# # Set title and subtitle
# ax.text(x=-2, y=46, s="'An Inconvenient Sequel: Truth To Power' is divisive", fontweight="bold", fontsize='12')
# ax.text(x=-2, y=43, s="IMDB ratings for the film as of Aug. 29", fontsize=12);

# # Set x and y-axis ticks
# ax.set_xticklabels(range(1,11), rotation=0)
# ax.set_yticks(range(0,50,10))
# ax.set_yticklabels(range(0,50,10))

# # Set axis labels
# plt.ylabel(ylabel='Percent of total votes', fontsize=9, fontweight='bold', labelpad=15)
# plt.xlabel(xlabel='Rating', fontsize=9, fontweight='bold', labelpad=15)

# plt.show();

# %%
#
