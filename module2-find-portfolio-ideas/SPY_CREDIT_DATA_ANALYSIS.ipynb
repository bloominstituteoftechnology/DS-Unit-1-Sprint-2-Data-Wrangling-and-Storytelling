# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spy_credit.csv')

# %%
df.head()
# Out:
#        Time    Open      High     Low  ...   OBR    Libor  Eff_Fed_FR Prim_cr_rate
# 0  09/16/19  299.84  301.1378  299.45  ...  2.18  2.11163        2.25         2.75
# 1  09/13/19  301.78  302.1700  300.68  ...  2.14  2.09475        2.14         2.75
# 2  09/12/19  301.25  302.4600  300.41  ...  2.13  2.08825        2.14         2.75
# 3  09/11/19  298.47  300.3400  297.75  ...  2.11   2.0945        2.14         2.75
# 4  09/10/19  297.36  298.2000  295.97  ...  2.11   2.0925        2.13         2.75
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (1824, 14)

# %%
df.isna().sum()
# Out:
# Time            899
# Open            899
# High            899
# Low             899
# Last            899
# Change          899
# Volume          899
# HYAS            899
# Baa_10Y         899
# HYBaa_OS        899
# OBR             899
# Libor           519
# Eff_Fed_FR        0
# Prim_cr_rate    522
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.head()
# Out:
#        Time    Open      High     Low  ...   OBR    Libor  Eff_Fed_FR Prim_cr_rate
# 0  09/16/19  299.84  301.1378  299.45  ...  2.18  2.11163        2.25         2.75
# 1  09/13/19  301.78  302.1700  300.68  ...  2.14  2.09475        2.14         2.75
# 2  09/12/19  301.25  302.4600  300.41  ...  2.13  2.08825        2.14         2.75
# 3  09/11/19  298.47  300.3400  297.75  ...  2.11   2.0945        2.14         2.75
# 4  09/10/19  297.36  298.2000  295.97  ...  2.11   2.0925        2.13         2.75
#
# [5 rows x 14 columns]

# %%
df2.shape
# Out:
# (925, 14)

# %%
df3 = df2.drop(["Open", "High", "Low"], axis=1)

# %%
df3.head()
# Out:
#        Time    Last  Change      Volume  ...   OBR    Libor Eff_Fed_FR Prim_cr_rate
# 0  09/16/19  300.16   -0.93  58191100.0  ...  2.18  2.11163       2.25         2.75
# 1  09/13/19  301.09   -0.20  62104800.0  ...  2.14  2.09475       2.14         2.75
# 2  09/12/19  301.29    1.04  72908704.0  ...  2.13  2.08825       2.14         2.75
# 3  09/11/19  300.25    2.12  68821000.0  ...  2.11   2.0945       2.14         2.75
# 4  09/10/19  298.13   -0.07  57947100.0  ...  2.11   2.0925       2.13         2.75
#
# [5 rows x 11 columns]

# %%
df3.dtypes
# Out:
# Time             object
# Last            float64
# Change          float64
# Volume          float64
# HYAS             object
# Baa_10Y          object
# HYBaa_OS         object
# OBR              object
# Libor            object
# Eff_Fed_FR      float64
# Prim_cr_rate     object
# dtype: object

# %%
df3.isna().sum()
# Out:
# Time            0
# Last            0
# Change          0
# Volume          0
# HYAS            0
# Baa_10Y         0
# HYBaa_OS        0
# OBR             0
# Libor           0
# Eff_Fed_FR      0
# Prim_cr_rate    0
# dtype: int64

# %%
df3["HYAS"] = df3.HYAS.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3["Baa_10Y"] = df3.Baa_10Y.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3["HYBaa_OS"] = df3.HYBaa_OS.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3["OBR"] = df3.OBR.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3["Libor"] = df3.Libor.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3["Prim_cr_rate"] = df3.Prim_cr_rate.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df3.dtypes
# Out:
# Time             object
# Last            float64
# Change          float64
# Volume          float64
# HYAS            float64
# Baa_10Y         float64
# HYBaa_OS        float64
# OBR             float64
# Libor           float64
# Eff_Fed_FR      float64
# Prim_cr_rate    float64
# dtype: object

# %%
df3.describe()
# Out:
#              Last      Change  ...  Eff_Fed_FR  Prim_cr_rate
# count  925.000000  925.000000  ...  925.000000    915.000000
# mean   251.163189    0.115135  ...    1.732876      1.967760
# std     30.629495    2.097271  ...    0.544048      0.734839
# min    182.860000  -11.520000  ...    0.660000      1.000000
# 25%    224.600000   -0.620000  ...    1.160000      1.250000
# 50%    255.790000    0.140000  ...    1.700000      2.000000
# 75%    277.850000    1.120000  ...    2.200000      2.750000
# max    302.010000   11.840000  ...    2.450000      3.000000
#
# [8 rows x 10 columns]

# %%
import matplotlib as plt
import seaborn as sns

# %%
sns.pairplot(df3)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
