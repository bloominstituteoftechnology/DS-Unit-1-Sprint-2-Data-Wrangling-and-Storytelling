# %% [markdown]
# <a href="https://colab.research.google.com/github/Pdugovich/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module2-find-portfolio-ideas/Ideas_for_Data_Storytelling_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ideas for data storytelling
#
# Schizophrenia, exercise, diet, autoimmune disorders, mental health,
#
# ## You
#
# - What do you care about?
#
# Schizophrenia, exercise, diet, autoimmune disorders, mental health, automation,
# societal health
#
#
# - What do you know about?
#
# mental health, fitness
#
#
# - What decisions do you face?
#
# Time management, dietary choices, life balance
#
# #First Example
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# ##Schizophrenia
#
# 1. Geographic Variation
#
# prevalence of schizophrenia by area(different frequency in areas with dense populations, colder climates, higher air polution, etc)
#
# 2. Trend related to the news
#
# Depictions of Schizophrenia in the media vs perception
#
# 3. Who does that?
#
# Prevalence by demographic
#
# 4. Answering a question people care about
#
# Diet of mothers while pregnant with a child who would go on to develop schizophrnia.
# Breastfeeding correlation(gut flora connection, immune system).
# Month baby was born(sunlight/vitD, liklihood of infection increase during winter months)
#
#
# 5. Valuable to businesses
#
# Unsure
#
# 6. What's the most popular?
#
# Popularity of medications prescribed for schizophrenia
#
# 7. Cost/Money rankings
#
# Cost of mental health services associated with Schizophrenia,
# avg income of people with schizophrenia,
#
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# Rates of violent crime.
# Ranking of expressed symptoms (not all experience hallucinations)
#
# ## Examples
#
# - What data storytelling example inspires you?
# https://wallethub.com/edu/happiest-states/6959/
#
# - Could you do a new hypothesis, for the same question?
#
# I might be able to put weights on the rankings that change the conclusion.
#
# - Could you do a new question, for the same topic?
#
# I could relate the index to another variable by state and see how they line up.
#
# - Could you do a new topic, with the same "style"?
#
# Yes. I like the style. I might make the colors for the map contrast a little more to show a greater distinction between states. I understand why they chose a light grade, though.
#
#
# ## Data
#
# Where could you search for data about your topic?
#
# CDC, WHO, NIMH
#
# #Second Example
#
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# ## Sense of Wellbeing
#
# 1. Geographic Variation
#
# Happiness by location, avg temperature, overcast days, altitude, population density.
#
# 2. Trend related to the news
#
# Sense of wellbeing over time in relation to major world events.
#
#
# 3. Who does that?
#
# Analysis on data gathered from people proclaiming to have exceptional sense of wellbeing (meditators, exercise enthusiasts, etc.)
#
#
# 4. Answering a question people care about
#
# What mimicable habits, diet, income level, biometrics are associated with happiness.
#
#
# 5. Valuable to businesses
#
# Effectiveness of products used for increasing wellbeing.
#
#
# 6. What's the most popular?
#
# What activity people say gives them the greatest sense of wellbeing.
#
#
# 7. Cost/Money rankings
#
# Methods of increasing wellbeing cost.
# Might be something like ranking the activities people say give them the greatest sense of wellbeing by cost(meditation ap, gym membership, yoga classes, just walking outside, etc.)
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# Happiness by income level. Consistent sense of wellbeing over time.
#
# ## Examples
#
# What data storytelling example inspires you?
#
# - https://www.vox.com/2015/5/11/8529217/40-years-of-a-changing-american-diet-in-one-massive-chart
#
# - Could you do a new hypothesis, for the same question?
#
# There might be conflicting data somewhere, but the conclusion seems pretty simple and cut and dried. Diet has changed over the decades.
#
# - Could you do a new question, for the same topic?
#
# I could certainly ask more about America's change in diet over the decades.
# I could compare the increase or decrease in a certain food or category of food with some condition.
#
# - Could you do a new topic, with the same "style"?
#
# This visualisation is simple and appealing to me. I could use this style for another topic.
#
# ## Data
#
# - Where could you search for data about your topic?
#
# A quick google search yields a ton of info on happiness by state. This topic should be pretty simple to find data for
#
# # Assignment!
#
# Fill out the above template *twice*, for two different ideas.
#
# Then compare and contrast and select one as the idea you're leaning towards
# working on for your project week.
