# %% [markdown]
# <a href="https://colab.research.google.com/github/bs3537/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/Bhav__Copy_of_LS_DS_124_Sequence_your_narrative_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Sequence Your Narrative - Assignment
#
# Today we will create a sequence of visualizations inspired by [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://www.youtube.com/watch?v=jbkSRLYSojo).
#
# Using this [data from Gapminder](https://github.com/open-numbers/ddf--gapminder--systema_globalis/):
# - [Income Per Person (GDP Per Capital, Inflation Adjusted) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv)
# - [Life Expectancy (in Years) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv)
# - [Population Totals, by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv)
# - [Entities](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv)
# - [Concepts](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv)

# %% [markdown]
# Objectives
# - sequence multiple visualizations
# - combine qualitative anecdotes with quantitative aggregates
#
# Links
# - [Hans Rosling’s TED talks](https://www.ted.com/speakers/hans_rosling)
# - [Spiralling global temperatures from 1850-2016](https://twitter.com/ed_hawkins/status/729753441459945474)
# - "[The Pudding](https://pudding.cool/) explains ideas debated in culture with visual essays."
# - [A Data Point Walks Into a Bar](https://lisacharlotterost.github.io/2016/12/27/datapoint-in-bar/): a thoughtful blog post about emotion and empathy in data storytelling

# %% [markdown]
# # ASSIGNMENT
#
#
# 1.   Replicate the Lesson Code
# 2.   Take it further by using the same gapminder dataset to create a sequence of visualizations that combined tell a story of your choosing.
#
# Get creative! Use text annotations to call out specific countries, maybe: change how the points are colored, change the opacity of the points, change their sized, pick a specific time window. Maybe only work with a subset of countries, change fonts, change background colors, etc. make it your own!

# %% [markdown]
# ## Replicating the lesson code

# %%
#Import required libraries

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
# Load required data in pandas dataframe
income = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')

# %%
income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
income.shape
# Out:
# (46513, 3)

# %%
income.isna().sum()
# Out:
# geo                                                      0
# time                                                     0
# income_per_person_gdppercapita_ppp_inflation_adjusted    0
# dtype: int64

# %%
income.describe()
# Out:
#                time  income_per_person_gdppercapita_ppp_inflation_adjusted
# count  46513.000000                                       46513.000000
# mean    1920.000000                                        6392.613871
# std       69.570856                                       13446.455483
# min     1800.000000                                         247.000000
# 25%     1860.000000                                         917.000000
# 50%     1920.000000                                        1635.000000
# 75%     1980.000000                                        4798.000000
# max     2040.000000                                      182339.000000

# %%
lifespan = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv')

# %%
population = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv')

# %%
entities = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv')

# %%
concepts = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv')

# %%
# find shape of the dataframes
income.shape, lifespan.shape, population.shape, entities.shape, concepts.shape
# Out:
# ((46513, 3), (44370, 3), (59297, 3), (273, 33), (590, 16))

# %%
#display the loaded dataframes

income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
lifespan.head()
# Out:
#    geo  time  life_expectancy_years
# 0  abw  1800                  34.42
# 1  abw  1801                  34.42
# 2  abw  1802                  34.42
# 3  abw  1803                  34.42
# 4  abw  1804                  34.42

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
entities.head()
# Out:
#   country alt_5  ... world_4region        world_6region
# 0    abkh   NaN  ...        europe  europe_central_asia
# 1     abw   NaN  ...      americas              america
# 2     afg   NaN  ...          asia           south_asia
# 3     ago   NaN  ...        africa   sub_saharan_africa
# 4     aia   NaN  ...      americas              america
#
# [5 rows x 33 columns]

# %%
concepts.head()
# Out:
#                                              concept  ...                        tags
# 0                  adults_with_hiv_percent_age_15_49  ...                         hiv
# 1                          age_at_1st_marriage_women  ...                  population
# 2                 aged_15_24_employment_rate_percent  ...             employment_rate
# 3               aged_15_24_unemployment_rate_percent  ...                unemployment
# 4  aged_15_64_labour_force_participation_rate_per...  ...  labour_force_participation
#
# [5 rows x 16 columns]

# %%
#merge income and lifespan dataframes with geophraphic location and time (years) as indexes and inner join.

# Inner join = An inner join combines two DataFrames based on a join key and returns a new DataFrame that contains only those rows that have matching values in both of the original DataFrames.

#Inner join yields a DataFrame that contains only rows where the value being joins exists in BOTH tables


df = pd.merge(income, lifespan, on=['geo', 'time'], how='inner')

# %%
df.head()
# Out:
#    geo  ...  life_expectancy_years
# 0  afg  ...                  28.21
# 1  afg  ...                  28.20
# 2  afg  ...                  28.19
# 3  afg  ...                  28.18
# 4  afg  ...                  28.17
#
# [5 rows x 4 columns]

# %%
df.shape
# Out:
# (40437, 4)

# %%
#merging above dataframe df with population dataframe

df2 = pd.merge(df, population)
df2.head()
# Out:
#    geo  time  ...  life_expectancy_years  population_total
# 0  afg  1800  ...                  28.21           3280000
# 1  afg  1801  ...                  28.20           3280000
# 2  afg  1802  ...                  28.19           3280000
# 3  afg  1803  ...                  28.18           3280000
# 4  afg  1804  ...                  28.17           3280000
#
# [5 rows x 5 columns]

# %%
entities.head()
# Out:
#   country alt_5  ... world_4region        world_6region
# 0    abkh   NaN  ...        europe  europe_central_asia
# 1     abw   NaN  ...      americas              america
# 2     afg   NaN  ...          asia           south_asia
# 3     ago   NaN  ...        africa   sub_saharan_africa
# 4     aia   NaN  ...      americas              america
#
# [5 rows x 33 columns]

# %%
subset_cols = ['country', 'name', 'world_4region', 'world_6region']
merged = pd.merge(df, entities[subset_cols], left_on='geo', right_on='country')
merged = merged.drop(columns=['geo'])
merged.head()
# Out:
#    time  ...  world_6region
# 0  1800  ...     south_asia
# 1  1801  ...     south_asia
# 2  1802  ...     south_asia
# 3  1803  ...     south_asia
# 4  1804  ...     south_asia
#
# [5 rows x 7 columns]

# %%
mapping_1 = {
    'time': 'year',
    'country': 'country_code',
    'income_per_person_gdppercapita_ppp_inflation_adjusted': 'income',
    'population_total': 'population',
    'world_4region': '4region',
    'world_6region': '6region',
    'life_expectancy_years': 'lifespan'
}
mapping_2 = {'name': 'country'}
merged = merged.rename(columns=mapping_1)
merged = merged.rename(columns=mapping_2)
merged.head()
# Out:
#    year  income  lifespan country_code      country 4region     6region
# 0  1800     603     28.21          afg  Afghanistan    asia  south_asia
# 1  1801     603     28.20          afg  Afghanistan    asia  south_asia
# 2  1802     603     28.19          afg  Afghanistan    asia  south_asia
# 3  1803     603     28.18          afg  Afghanistan    asia  south_asia
# 4  1804     603     28.17          afg  Afghanistan    asia  south_asia

# %%
merged.dtypes
# Out:
# year              int64
# income            int64
# lifespan        float64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
merged.describe()
# Out:
#                year         income      lifespan
# count  40437.000000   40437.000000  40437.000000
# mean    1909.292900    4619.492717     43.132080
# std       63.308682   10209.571045     16.313228
# min     1800.000000     247.000000      1.000000
# 25%     1854.000000     876.000000     31.160000
# 50%     1909.000000    1442.000000     35.500000
# 75%     1964.000000    3488.000000     55.970000
# max     2018.000000  177522.000000     84.170000

# %%
merged.describe(exclude='number')
# Out:
#        country_code country 4region              6region
# count         40437   40437   40437                40437
# unique          187     187       4                    6
# top             gin   Ghana  africa  europe_central_asia
# freq            219     219   11826                10778

# %%
merged['country'].value_counts()
# Out:
# Ghana                     219
# Tanzania                  219
# Ecuador                   219
# Belize                    219
# Cuba                      219
# Vanuatu                   219
# Fiji                      219
# Congo, Rep.               219
# Malaysia                  219
# Slovenia                  219
# Suriname                  219
# Tunisia                   219
# India                     219
# Mongolia                  219
# Chile                     219
# Seychelles                219
# Brazil                    219
# Ireland                   219
# Indonesia                 219
# Montenegro                219
# Australia                 219
# Serbia                    219
# Togo                      219
# Malawi                    219
# Slovak Republic           219
# Lao                       219
# Bolivia                   219
# Lesotho                   219
# Bulgaria                  219
# Bosnia and Herzegovina    219
#                          ...
# ...

# %%
mask_usa = merged['country'] == 'United States'
usa = merged[mask_usa]
usa.head()
# Out:
#        year  income  lifespan country_code        country   4region  6region
# 38028  1800    2127     39.41          usa  United States  americas  america
# 38029  1801    2167     39.41          usa  United States  americas  america
# 38030  1802    2202     39.41          usa  United States  americas  america
# 38031  1803    2166     39.41          usa  United States  americas  america
# 38032  1804    2165     39.41          usa  United States  americas  america

# %%
usa[usa['year'].isin([1818, 1918, 2018])]
# Out:
#        year  income  lifespan country_code        country   4region  6region
# 38046  1818    2258     39.41          usa  United States  americas  america
# 38146  1918    9371     47.18          usa  United States  americas  america
# 38246  2018   54898     79.14          usa  United States  americas  america

# %%
mask_china = merged['country'] == 'China'
china = merged[mask_china]
china[china['year'].isin([1818, 1918, 2018])]
# Out:
#       year  income  lifespan country_code country 4region            6region
# 6854  1818     985     32.00          chn   China    asia  east_asia_pacific
# 6954  1918     989     22.13          chn   China    asia  east_asia_pacific
# 7054  2018   16018     76.92          chn   China    asia  east_asia_pacific

# %%
# Data Visualization

import seaborn as sns

#now = merged[merged['year'].isin([2018])]
now = merged[merged['year'] == 2018]
now.head()
# Out:
#       year  income  ...   4region                   6region
# 218   2018    1867  ...      asia                south_asia
# 437   2018    5846  ...    africa        sub_saharan_africa
# 656   2018   12424  ...    europe       europe_central_asia
# 922   2018   68231  ...      asia  middle_east_north_africa
# 1141  2018   18942  ...  americas                   america
#
# [5 rows x 7 columns]

# %%
sns.relplot(x='income', 
            y='lifespan', 
            hue='6region',
            data=now);
plt.xscale('log')
plt.ylim([30, 90])
plt.title('The World in 2018');

# %%
#Analyze outliers

now.sort_values('income')
# Out:
#        year  income  ...   4region                   6region
# 32771  2018     629  ...    africa        sub_saharan_africa
# 6178   2018     689  ...    africa        sub_saharan_africa
# 2455   2018     691  ...    africa        sub_saharan_africa
# 7711   2018     751  ...    africa        sub_saharan_africa
# 20898  2018     801  ...    africa        sub_saharan_africa
# 26420  2018     949  ...    africa        sub_saharan_africa
# 25763  2018    1134  ...    africa        sub_saharan_africa
# 25106  2018    1196  ...    africa        sub_saharan_africa
# 11262  2018    1252  ...    africa        sub_saharan_africa
# 13890  2018    1282  ...    africa        sub_saharan_africa
# 29486  2018    1387  ...      asia         east_asia_pacific
# 8368   2018    1439  ...    africa        sub_saharan_africa
# 23088  2018    1455  ...    africa        sub_saharan_africa
# 35399  2018    1478  ...    africa        sub_saharan_africa
# ...

# %%
now.sort_values('income', ascending=False)
# Out:
#        year  income  ...   4region                   6region
# 30362  2018  121033  ...      asia  middle_east_north_africa
# 22212  2018   99034  ...    europe       europe_central_asia
# 31895  2018   83888  ...      asia         east_asia_pacific
# 5521   2018   76943  ...      asia         east_asia_pacific
# 20241  2018   68359  ...      asia  middle_east_north_africa
# 922    2018   68231  ...      asia  middle_east_north_africa
# 16956  2018   65622  ...    europe       europe_central_asia
# 27296  2018   64846  ...    europe       europe_central_asia
# 6616   2018   57133  ...    europe       europe_central_asia
# 38246  2018   54898  ...  americas                   america
# 31238  2018   50114  ...      asia  middle_east_north_africa
# 27077  2018   48542  ...    europe       europe_central_asia
# 34304  2018   47520  ...    europe       europe_central_asia
# 17613  2018   47356  ...    europe       europe_central_asia
# ...

# %%
now.sort_values('lifespan', ascending=False)
# Out:
#        year  income  ...   4region                   6region
# 18708  2018   39105  ...      asia         east_asia_pacific
# 31895  2018   83888  ...      asia         east_asia_pacific
# 6616   2018   57133  ...    europe       europe_central_asia
# 11481  2018   34742  ...    europe       europe_central_asia
# 1798   2018   45783  ...      asia         east_asia_pacific
# 12576  2018   39006  ...    europe       europe_central_asia
# 18051  2018   35192  ...    europe       europe_central_asia
# 17613  2018   47356  ...    europe       europe_central_asia
# 17832  2018   33434  ...      asia  middle_east_north_africa
# 27296  2018   64846  ...    europe       europe_central_asia
# 22212  2018   99034  ...    europe       europe_central_asia
# 34304  2018   47520  ...    europe       europe_central_asia
# 6397   2018   43773  ...  americas                   america
# 12138  2018   40290  ...    europe       europe_central_asia
# ...

# %%
# Using numpy to find correlation coeeficient between lifespan and income

np.corrcoef(now['lifespan'], now['income'])
# Out:
# array([[1.        , 0.67035369],
#        [0.67035369, 1.        ]])

# %%
df_1990 = merged[merged['year'] == 1990]
np.corrcoef(df_1990['lifespan'], df_1990['income'])[0][1]
# Out:
# 0.5665901206189361

# %%
years = range(1900, 2019)
corr_list = []

for year in years:
  df_year = merged[merged['year'] == year]
  corr = np.corrcoef(df_year['lifespan'], df_year['income'])[0][1]
  corr_list.append(corr)
  
corr_arr = np.array(corr_list)

# %%
year_arr = np.array(years)

# %%
np.argmax(corr_arr)
# Out:
# 34

# %%
year_arr[34]
# Out:
# 1934

# %%
plt.scatter(year_arr, corr_arr);

# %%
now_qatar = now[now['country'] == 'Qatar']
now_qatar.head()
# Out:
#        year  income  lifespan  ... country 4region                   6region
# 30362  2018  121033     80.71  ...   Qatar    asia  middle_east_north_africa
#
# [1 rows x 7 columns]

# %%
now_qatar['income'].values[0]
# Out:
# 121033

# %%
sns.relplot(x='income', 
            y='lifespan', 
            hue='6region', 
            data=now
           )
plt.xscale('log')
plt.ylim([30, 90])
plt.title('The World in 2018')
plt.text(x=now_qatar['income'].values[0]-2000, 
         y=now_qatar['lifespan'].values[0]-2, 
         s='Qatar')
# Out:
# Text(119033, 78.71, 'Qatar')

# %%
sns.relplot(x='income', 
            y='lifespan', 
            hue='6region', 
            data=now
           )
plt.xscale('log')
plt.ylim([30, 90])
plt.title('The World in 2018')
plt.text(x=now_qatar['income'].values[0]-10000, 
         y=now_qatar['lifespan'].values[0]-7, 
         s='Qatar')
plt.arrow(x=now_qatar['income'].values[0],
         y=now_qatar['lifespan'].values[0],
         dx=0,
         dy=-5
         )

# %%
# Plot multiple years

years = [1918, 1948, 1978, 2008]

for year in years:
  df_year = merged[merged['year']==year]
  sns.relplot(x='income', 
              y='lifespan', 
              hue='6region',
              data=df_year);
  plt.xscale('log')
  plt.ylim([0, 90])
  plt.title(f'The World in {year}')

# %%
# Using Plotly

import plotly.express as px

px.scatter(merged, 
           x='income', 
           y='lifespan',
           animation_frame='year',
           color='6region',
           log_x=True,
           hover_name='country'
          )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a513f9a4-d620-44b1-a853-ced01845e080" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a513f9a4-d620-44b1-a853-ced01845e080")) {
#                     Plotly.newPlot(
#                         'a513f9a4-d620-44b1-a853-ced01845e080',
# ...

# %% [markdown]
# ###Take it further by using the same gapminder dataset to create a sequence of visualizations that combined tell a story of your choosing.

# %%
# Let us check where India stands.

now_india = now[now['country'] == 'India']
now_india.head()
# Out:
#        year  income  lifespan country_code country 4region     6region
# 16737  2018    6890      69.1          ind   India    asia  south_asia

# %%
now_india['income'].values[0]
# Out:
# 6890

# %%
sns.relplot(x='income', 
            y='lifespan', 
            hue='6region', 
            data=now
           )
plt.xscale('log')
plt.ylim([30, 90])
plt.title('The World in 2018: Where does India stand?')
plt.text(x=now_india['income'].values[0]-2000, 
         y=now_india['lifespan'].values[0]-2, 
         s='India')
# Out:
# Text(4890, 67.1, 'India')

# %% [markdown]
# ###India ia ranked in the middle of this scatter plot showing income and lifespan.

# %% [markdown]
# ### Let us check Singapore which has one the highest GDP per capita in the world

# %%
now_singapore = now[now['country'] == 'Singapore']
now_singapore.head()
# Out:
#        year  income  lifespan  ...    country 4region            6region
# 31895  2018   83888     84.03  ...  Singapore    asia  east_asia_pacific
#
# [1 rows x 7 columns]

# %%
now_singapore['income'].values[0]
# Out:
# 83888

# %%
sns.relplot(x='income', 
            y='lifespan', 
            hue='6region', 
            data=now
           )
plt.xscale('log')
plt.ylim([30, 90])
plt.title('The World in 2018: Where does Singapore stand?')
plt.text(x=now_singapore['income'].values[0]-2000, 
         y=now_singapore['lifespan'].values[0]-2, 
         s='Singapore')
# Out:
# Text(81888, 82.03, 'Singapore')

# %% [markdown]
# ### Singapore ranks high on this scatter plot in terms of lifespan and income.

# %% [markdown]
# # STRETCH OPTIONS
#
# ## 1. Animate!
#
# - [How to Create Animated Graphs in Python](https://towardsdatascience.com/how-to-create-animated-graphs-in-python-bb619cc2dec1)
# - Try using [Plotly](https://plot.ly/python/animations/)!
# - [The Ultimate Day of Chicago Bikeshare](https://chrisluedtke.github.io/divvy-data.html) (Lambda School Data Science student)
# - [Using Phoebe for animations in Google Colab](https://colab.research.google.com/github/phoebe-project/phoebe2-docs/blob/2.1/tutorials/animations.ipynb)
#
# ## 2. Study for the Sprint Challenge
#
# - Concatenate DataFrames
# - Merge DataFrames
# - Reshape data with `pivot_table()` and `.melt()`
# - Be able to reproduce a FiveThirtyEight graph using Matplotlib or Seaborn.
#
# ## 3. Work on anything related to your portfolio site / Data Storytelling Project

# %%
# TODO
