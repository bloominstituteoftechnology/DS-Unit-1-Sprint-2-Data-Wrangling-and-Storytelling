# %% [markdown]
# <a href="https://colab.research.google.com/github/johanaluna/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module4-sequence-your-narrative/Johana_LS_DS7_124_Sequence_your_narrative_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Sequence Your Narrative - Assignment
#
# Today we will create a sequence of visualizations inspired by [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://www.youtube.com/watch?v=jbkSRLYSojo).
#
# Using this [data from Gapminder](https://github.com/open-numbers/ddf--gapminder--systema_globalis/):
# - [Income Per Person (GDP Per Capital, Inflation Adjusted) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv)
# - [Life Expectancy (in Years) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv)
# - [Population Totals, by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv)
# - [Entities](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv)
# - [Concepts](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv)

# %% [markdown]
# Objectives
# - sequence multiple visualizations
# - combine qualitative anecdotes with quantitative aggregates
#
# Links
# - [Hans Rosling’s TED talks](https://www.ted.com/speakers/hans_rosling)
# - [Spiralling global temperatures from 1850-2016](https://twitter.com/ed_hawkins/status/729753441459945474)
# - "[The Pudding](https://pudding.cool/) explains ideas debated in culture with visual essays."
# - [A Data Point Walks Into a Bar](https://lisacharlotterost.github.io/2016/12/27/datapoint-in-bar/): a thoughtful blog post about emotion and empathy in data storytelling

# %% [markdown]
# # ASSIGNMENT
#
#
# 1.   Replicate the Lesson Code
# 2.   Take it further by using the same gapminder dataset to create a sequence of visualizations that combined tell a story of your choosing.
#
# Get creative! Use text annotations to call out specific countries, maybe: change how the points are colored, change the opacity of the points, change their sized, pick a specific time window. Maybe only work with a subset of countries, change fonts, change background colors, etc. make it your own!

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.9.0'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
income = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')

# %%
lifespan = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv')

# %%
population = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv')

# %%
entities = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv')

# %%
concepts = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv')

# %%
income.shape, lifespan.shape, population.shape, entities.shape, concepts.shape
# Out:
# ((46513, 3), (44370, 3), (59297, 3), (273, 33), (590, 16))

# %%
income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
lifespan.head()
# Out:
#    geo  time  life_expectancy_years
# 0  abw  1800                  34.42
# 1  abw  1801                  34.42
# 2  abw  1802                  34.42
# 3  abw  1803                  34.42
# 4  abw  1804                  34.42

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
entities.head()
# Out:
#   country alt_5  ... world_4region        world_6region
# 0    abkh   NaN  ...        europe  europe_central_asia
# 1     abw   NaN  ...      americas              america
# 2     afg   NaN  ...          asia           south_asia
# 3     ago   NaN  ...        africa   sub_saharan_africa
# 4     aia   NaN  ...      americas              america
#
# [5 rows x 33 columns]

# %%
concepts.head()
# Out:
#                                              concept  ...                        tags
# 0                  adults_with_hiv_percent_age_15_49  ...                         hiv
# 1                          age_at_1st_marriage_women  ...                  population
# 2                 aged_15_24_employment_rate_percent  ...             employment_rate
# 3               aged_15_24_unemployment_rate_percent  ...                unemployment
# 4  aged_15_64_labour_force_participation_rate_per...  ...  labour_force_participation
#
# [5 rows x 16 columns]

# %%
##CONSOLIDATE DATA
df=pd.merge(income,lifespan, on=['geo','time'], how='inner')
df.head()
# Out:
#    geo  ...  life_expectancy_years
# 0  afg  ...                  28.21
# 1  afg  ...                  28.20
# 2  afg  ...                  28.19
# 3  afg  ...                  28.18
# 4  afg  ...                  28.17
#
# [5 rows x 4 columns]

# %%
df=pd.merge(df,population)
print(df.shape)
df.head()
# Out:
# (40437, 5)
#    geo  time  ...  life_expectancy_years  population_total
# 0  afg  1800  ...                  28.21           3280000
# 1  afg  1801  ...                  28.20           3280000
# 2  afg  1802  ...                  28.19           3280000
# 3  afg  1803  ...                  28.18           3280000
# 4  afg  1804  ...                  28.17           3280000
#
# [5 rows x 5 columns]

# %%
entities.head()
# Out:
#   country alt_5  ... world_4region        world_6region
# 0    abkh   NaN  ...        europe  europe_central_asia
# 1     abw   NaN  ...      americas              america
# 2     afg   NaN  ...          asia           south_asia
# 3     ago   NaN  ...        africa   sub_saharan_africa
# 4     aia   NaN  ...      americas              america
#
# [5 rows x 33 columns]

# %%
entities['world_6region'].value_counts()
# Out:
# europe_central_asia         77
# america                     53
# sub_saharan_africa          53
# east_asia_pacific           46
# middle_east_north_africa    23
# south_asia                   8
# Name: world_6region, dtype: int64

# %%
entities['world_4region'].value_counts()
# Out:
# asia        80
# europe      73
# africa      61
# americas    57
# Name: world_4region, dtype: int64

# %%
entity_columns_to_keep = ['country', 'name', 'world_4region', 'world_6region']
entities = entities[entity_columns_to_keep]
entities.head()
# Out:
#   country         name world_4region        world_6region
# 0    abkh     Abkhazia        europe  europe_central_asia
# 1     abw        Aruba      americas              america
# 2     afg  Afghanistan          asia           south_asia
# 3     ago       Angola        africa   sub_saharan_africa
# 4     aia     Anguilla      americas              america

# %%
merged = pd.merge(df, entities, left_on='geo', right_on='country') #left is DF in column (geo) but in entities the colomn name is country

merged.head()
# Out:
#    geo  time  ...  world_4region  world_6region
# 0  afg  1800  ...           asia     south_asia
# 1  afg  1801  ...           asia     south_asia
# 2  afg  1802  ...           asia     south_asia
# 3  afg  1803  ...           asia     south_asia
# 4  afg  1804  ...           asia     south_asia
#
# [5 rows x 9 columns]

# %%
merged = merged.drop('geo', axis='columns') #eliminate column geo
merged.head()
# Out:
#    time  ...  world_6region
# 0  1800  ...     south_asia
# 1  1801  ...     south_asia
# 2  1802  ...     south_asia
# 3  1803  ...     south_asia
# 4  1804  ...     south_asia
#
# [5 rows x 8 columns]

# %%
#Change names of the columns

merged = merged.rename(columns = {
    'country': 'country_code',
    'time': 'year', 
    'income_per_person_gdppercapita_ppp_inflation_adjusted': 'income', 
    'life_expectancy_years': 'lifespan',
    'population_total': 'population',
    'name': 'country',
    'world_6region': '6region',
    'world_4region': '4region'
})

merged.head()
# Out:
#    year  income  lifespan  ...      country 4region     6region
# 0  1800     603     28.21  ...  Afghanistan    asia  south_asia
# 1  1801     603     28.20  ...  Afghanistan    asia  south_asia
# 2  1802     603     28.19  ...  Afghanistan    asia  south_asia
# 3  1803     603     28.18  ...  Afghanistan    asia  south_asia
# 4  1804     603     28.17  ...  Afghanistan    asia  south_asia
#
# [5 rows x 8 columns]

# %%
##EXPLORE DATA
merged.dtypes
# Out:
# year              int64
# income            int64
# lifespan        float64
# population        int64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
merged.describe()
# Out:
#                year         income      lifespan    population
# count  40437.000000   40437.000000  40437.000000  4.043700e+04
# mean    1909.292900    4619.492717     43.132080  1.371204e+07
# std       63.308682   10209.571045     16.313228  6.606335e+07
# min     1800.000000     247.000000      1.000000  2.128000e+03
# 25%     1854.000000     876.000000     31.160000  4.113310e+05
# 50%     1909.000000    1442.000000     35.500000  1.985952e+06
# 75%     1964.000000    3488.000000     55.970000  6.499707e+06
# max     2018.000000  177522.000000     84.170000  1.415046e+09

# %%
merged.describe(exclude='number') #shows numbers without decimals
# Out:
#        country_code   country 4region              6region
# count         40437     40437   40437                40437
# unique          187       187       4                    6
# top             lso  Pakistan  africa  europe_central_asia
# freq            219       219   11826                10778

# %%
#show uique values of the column country
merged.country.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bolivia', 'Brazil', 'Barbados', 'Brunei',
#        'Bhutan', 'Botswana', 'Central African Republic', 'Canada',
#        'Switzerland', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic',
#        'Algeria', 'Ecuador', 'Egypt', 'Eritrea', 'Spain', 'Estonia',
#        'Ethiopia', 'Finland', 'Fiji', 'France', 'Micronesia, Fed. Sts.',
#        'Gabon', 'United Kingdom', 'Georgia', 'Ghana', 'Guinea', 'Gambia',
# ...

# %%
colombia = merged[merged.country == 'Colombia']
colombia.head(10)
# Out:
#       year  income  lifespan  ...   country   4region  6region
# 7931  1800     962      32.0  ...  Colombia  americas  america
# 7932  1801     962      32.0  ...  Colombia  americas  america
# 7933  1802     962      32.0  ...  Colombia  americas  america
# 7934  1803     963      32.0  ...  Colombia  americas  america
# 7935  1804     963      32.0  ...  Colombia  americas  america
# 7936  1805     963      32.0  ...  Colombia  americas  america
# 7937  1806     963      32.0  ...  Colombia  americas  america
# 7938  1807     963      32.0  ...  Colombia  americas  america
# 7939  1808     963      32.0  ...  Colombia  americas  america
# 7940  1809     963      32.0  ...  Colombia  americas  america
#
# [10 rows x 8 columns]

# %%
colombia[colombia.year.isin([1818,1868,1918,1968,2018])]
# Out:
#       year  income  lifespan  ...   country   4region  6region
# 7949  1818     965     32.00  ...  Colombia  americas  america
# 7999  1868    1092     32.00  ...  Colombia  americas  america
# 8049  1918    1630     29.41  ...  Colombia  americas  america
# 8099  1968    3942     65.14  ...  Colombia  americas  america
# 8149  2018   13704     78.62  ...  Colombia  americas  america
#
# [5 rows x 8 columns]

# %%
usa = merged[merged.country == 'United States']
usa.head()
# Out:
#        year  income  lifespan  ...        country   4region  6region
# 38028  1800    2127     39.41  ...  United States  americas  america
# 38029  1801    2167     39.41  ...  United States  americas  america
# 38030  1802    2202     39.41  ...  United States  americas  america
# 38031  1803    2166     39.41  ...  United States  americas  america
# 38032  1804    2165     39.41  ...  United States  americas  america
#
# [5 rows x 8 columns]

# %%
usa[usa.year.isin([1818,1868,1918,1968,2018])]
# Out:
#        year  income  lifespan  ...        country   4region  6region
# 38046  1818    2258     39.41  ...  United States  americas  america
# 38096  1868    4064     39.41  ...  United States  americas  america
# 38146  1918    9371     47.18  ...  United States  americas  america
# 38196  1968   23647     70.36  ...  United States  americas  america
# 38246  2018   54898     79.14  ...  United States  americas  america
#
# [5 rows x 8 columns]

# %%
japan = merged[merged.country == 'Japan']
japan.head()
# Out:
#        year  income  lifespan  ...  country 4region            6region
# 18490  1800    1049      36.4  ...    Japan    asia  east_asia_pacific
# 18491  1801    1051      36.4  ...    Japan    asia  east_asia_pacific
# 18492  1802    1052      36.4  ...    Japan    asia  east_asia_pacific
# 18493  1803    1054      36.4  ...    Japan    asia  east_asia_pacific
# 18494  1804    1055      36.4  ...    Japan    asia  east_asia_pacific
#
# [5 rows x 8 columns]

# %%
japan[japan.year.isin([1818,1868,1918,1968,2018])]
# Out:
#        year  income  lifespan  ...  country 4region            6region
# 18508  1818    1076     36.41  ...    Japan    asia  east_asia_pacific
# 18558  1868    1203     36.53  ...    Japan    asia  east_asia_pacific
# 18608  1918    2475     32.75  ...    Japan    asia  east_asia_pacific
# 18658  1968    9637     71.96  ...    Japan    asia  east_asia_pacific
# 18708  2018   39105     84.17  ...    Japan    asia  east_asia_pacific
#
# [5 rows x 8 columns]

# %%
merged.year.unique()
# Out:
# array([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810,
#        1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821,
#        1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832,
#        1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843,
#        1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854,
#        1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865,
#        1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876,
#        1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887,
#        1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898,
#        1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909,
#        1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920,
#        1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931,
#        1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942,
# ...

# %%
##VISUALIZATION

import seaborn as sns

now = merged[merged.year == 2018]

now.head()
# sns.relplot(x=now.income, y=now.lifespan)
# Out:
#       year  income  ...   4region                   6region
# 218   2018    1867  ...      asia                south_asia
# 437   2018    5846  ...    africa        sub_saharan_africa
# 656   2018   12424  ...    europe       europe_central_asia
# 922   2018   68231  ...      asia  middle_east_north_africa
# 1141  2018   18942  ...  americas                   america
#
# [5 rows x 8 columns]

# %%
# import matplotlib.pyplot as plt
sns.relplot(x='income', y='lifespan', hue='4region', size='population', sizes=(30,400), data=now)
plt.xscale('log')
plt.ylim(20,85)
plt.title("The World in 2018")
plt.show()

# %%
# China is the most populous country in  2018
now.sort_values('population', ascending=False)
# Out:
#        year  income  ...   4region                   6region
# 7054   2018   16018  ...      asia         east_asia_pacific
# 16737  2018    6890  ...      asia                south_asia
# 38246  2018   54898  ...  americas                   america
# 16518  2018   11650  ...      asia         east_asia_pacific
# 5083   2018   14341  ...  americas                   america
# 28172  2018    5221  ...      asia                south_asia
# 26639  2018    5569  ...    africa        sub_saharan_africa
# 3331   2018    3722  ...      asia                south_asia
# 30800  2018   24786  ...    europe       europe_central_asia
# 23526  2018   17288  ...  americas                   america
# 18708  2018   39105  ...      asia         east_asia_pacific
# 11919  2018    1801  ...    africa        sub_saharan_africa
# 28829  2018    7957  ...      asia         east_asia_pacific
# 11043  2018   10848  ...    africa  middle_east_north_africa
# ...

# %%
#Japan is the country whit the highest lifespan
now.sort_values('lifespan', ascending=False)
# Out:
#        year  income  ...   4region                   6region
# 18708  2018   39105  ...      asia         east_asia_pacific
# 31895  2018   83888  ...      asia         east_asia_pacific
# 6616   2018   57133  ...    europe       europe_central_asia
# 11481  2018   34742  ...    europe       europe_central_asia
# 1798   2018   45783  ...      asia         east_asia_pacific
# 12576  2018   39006  ...    europe       europe_central_asia
# 18051  2018   35192  ...    europe       europe_central_asia
# 17613  2018   47356  ...    europe       europe_central_asia
# 17832  2018   33434  ...      asia  middle_east_north_africa
# 27296  2018   64846  ...    europe       europe_central_asia
# 22212  2018   99034  ...    europe       europe_central_asia
# 34304  2018   47520  ...    europe       europe_central_asia
# 6397   2018   43773  ...  americas                   america
# 12138  2018   40290  ...    europe       europe_central_asia
# ...

# %%
now_japan = now[now.country=='Japan']
now_japan.head()
# Out:
#        year  income  lifespan  ...  country 4region            6region
# 18708  2018   39105     84.17  ...    Japan    asia  east_asia_pacific
#
# [1 rows x 8 columns]

# %%
sns.relplot(x='income', y='lifespan', hue='6region', size='population', sizes=(30,400), data=now)
plt.xscale('log')
plt.ylim(20,85)
plt.title("The World in 2018")
plt.text(x=now_japan.income-5000, y= now_japan.lifespan+1, s='Japan')
plt.show()

# %%
now_colombia = now[now.country=='Colombia']
now_colombia.head()
# Out:
#       year  income  lifespan  ...   country   4region  6region
# 8149  2018   13704     78.62  ...  Colombia  americas  america
#
# [1 rows x 8 columns]

# %%
sns.relplot(x='income', y='lifespan', hue='6region', size='population', sizes=(30,400), data=now)
plt.xscale('log')
plt.ylim(20,85)
plt.title("The World in 2018")
plt.text(x=now_colombia.income-5000, y= now_colombia.lifespan+1, s='Colombia')
plt.show()

# %%
years = [1818,1868, 1918,2018]

centuries = merged[merged.year.isin(years)]

# sns.set(rc={'axes.facecolor':'gray', 'figure.facecolor':'white'})

fig = sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
                  sizes=(30,600), col='year', data=centuries)
plt.xscale('log')
plt.text(x=now_colombia.income-5000, y= now_colombia.lifespan+1, s='Colombia')

plt.show()

# %%
years = [1918, 1938, 1978, 1998, 2018]

decades = merged[merged.year.isin(years)]
sns.relplot(x='income', y='lifespan', hue='6region', size='population', col='year', data=decades)
plt.show()

# %%
for year in years:
  sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
                data=merged[merged.year==year])
  plt.xscale('log')
  plt.xlim((150, 150000))
  plt.ylim((0, 90))
  plt.title(year)
  plt.axvline(x=1000, color='grey')
  plt.axhline(y=40, color='grey')

# %%
merged.head()
# Out:
#    year  income  lifespan  ...      country 4region     6region
# 0  1800     603     28.21  ...  Afghanistan    asia  south_asia
# 1  1801     603     28.20  ...  Afghanistan    asia  south_asia
# 2  1802     603     28.19  ...  Afghanistan    asia  south_asia
# 3  1803     603     28.18  ...  Afghanistan    asia  south_asia
# 4  1804     603     28.17  ...  Afghanistan    asia  south_asia
#
# [5 rows x 8 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

# %%
mcolor = range(0,len(merged))
years = [1918, 1938, 1978, 1998, 2018]

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96
 
# For each year:
for i in years:
 
# initialize a figure
  fig = plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# Change color with c and alpha. I map the color to the X axis value.
  tmp=merged[ merged.year == i ]
  plt.scatter(merged['lifespan'], merged['income'] , s=merged['population']/200000 , c=mcolor, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
 
 # Add titles (main and on axis)/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
 
# Add titles (main and on axis)
  plt.yscale('log')
  plt.xlabel("Life Expectancy")
  plt.ylabel("GDP per Capita")
  plt.title("Year: "+str(i) )
  plt.ylim(0,100000)
  plt.xlim(30, 90)
 
# Save it
  filename='Gapminder_step'+str(i)+'.png'

  anim.save('sine_wave.gif', writer='imagemagick')
  plt.savefig(filename, dpi=96)
  plt.gca()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:1479: UserWarning:
#
# Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-9ff1f0b40f9b> in <module>()
#      32   filename='Gapminder_step'+str(i)+'.png'
#      33
# ---> 34   anim.save('sine_wave.gif', writer='imagemagick')
#      35   plt.savefig(filename, dpi=96)
#      36   plt.gca()
#
# NameError: name 'anim' is not defined

# %%
# !pip install plotly --upgrade
# Out:
# ...
#      |████████████████████████████████| 7.1MB 4.8MB/s
# ...
#   Found existing installation: plotly 3.6.1
#     Uninstalling plotly-3.6.1:
#       Successfully uninstalled plotly-3.6.1
# ...

# %%
import plotly.express as px
px.scatter(merged, x="income", y="lifespan", animation_frame="year", animation_group="country",
           size="population", color="6region", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d2d8c73f-8311-45d2-831f-f0d934f90e28" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2d8c73f-8311-45d2-831f-f0d934f90e28")) {
#                     Plotly.newPlot(
#                         'd2d8c73f-8311-45d2-831f-f0d934f90e28',
# ...

# %% [markdown]
# # STRETCH OPTIONS
#
# ## 1. Animate!
#
# - [How to Create Animated Graphs in Python](https://towardsdatascience.com/how-to-create-animated-graphs-in-python-bb619cc2dec1)
# - Try using [Plotly](https://plot.ly/python/animations/)!
# - [The Ultimate Day of Chicago Bikeshare](https://chrisluedtke.github.io/divvy-data.html) (Lambda School Data Science student)
# - [Using Phoebe for animations in Google Colab](https://colab.research.google.com/github/phoebe-project/phoebe2-docs/blob/2.1/tutorials/animations.ipynb)
#
# ## 2. Study for the Sprint Challenge
#
# - Concatenate DataFrames
# - Merge DataFrames
# - Reshape data with `pivot_table()` and `.melt()`
# - Be able to reproduce a FiveThirtyEight graph using Matplotlib or Seaborn.
#
# ## 3. Work on anything related to your portfolio site / Data Storytelling Project

# %%
import plotly.express as px
px.scatter(colombia, x="income", y="lifespan", animation_frame="year", animation_group="country",
           size="population", color="6region", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bd35e76d-4e60-4e21-982a-841d8781ecdd" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd35e76d-4e60-4e21-982a-841d8781ecdd")) {
#                     Plotly.newPlot(
#                         'bd35e76d-4e60-4e21-982a-841d8781ecdd',
# ...

# %%
# TODO
