# %% [markdown]
# <a href="https://colab.research.google.com/github/Nckflannery/DS-Unit-1-Sprint-2-Data-Wrangling-and-Storytelling/blob/master/module4-sequence-your-narrative/Notes_LS_DS_124_Sequence_your_narrative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
#
# # Sequence your narrative
#
# Today we will create a sequence of visualizations inspired by [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://www.youtube.com/watch?v=jbkSRLYSojo).
#
# Using this [data from Gapminder](https://github.com/open-numbers/ddf--gapminder--systema_globalis/):
# - [Income Per Person (GDP Per Capital, Inflation Adjusted) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv)
# - [Life Expectancy (in Years) by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv)
# - [Population Totals, by Geo & Time](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv)
# - [Entities](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv)
# - [Concepts](https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv)

# %% [markdown]
# Objectives
# - sequence multiple visualizations
# - combine qualitative anecdotes with quantitative aggregates
#
# Links
# - [Hans Rosling’s TED talks](https://www.ted.com/speakers/hans_rosling)
# - [Spiralling global temperatures from 1850-2016](https://twitter.com/ed_hawkins/status/729753441459945474)
# - "[The Pudding](https://pudding.cool/) explains ideas debated in culture with visual essays."
# - [A Data Point Walks Into a Bar](https://lisacharlotterost.github.io/2016/12/27/datapoint-in-bar/): a thoughtful blog post about emotion and empathy in data storytelling

# %% [markdown]
# ## Make a plan
#
# #### How to present the data?
#
# Variables --> Visual Encodings
# - Income --> x
# - Lifespan --> y
# - Region --> color
# - Population --> size
# - Year --> animation frame (alternative: small multiple)
# - Country --> annotation
#
# Qualitative --> Verbal
# - Editorial / contextual explanation --> audio narration (alternative: text)
#
#
# #### How to structure the data?
#
# | Year | Country | Region   | Income | Lifespan | Population |
# |------|---------|----------|--------|----------|------------|
# | 1818 | USA     | Americas | ###    | ##       | #          |
# | 1918 | USA     | Americas | ####   | ###      | ##         |
# | 2018 | USA     | Americas | #####  | ###      | ###        |
# | 1818 | China   | Asia     | #      | #        | #          |
# | 1918 | China   | Asia     | ##     | ##       | ###        |
# | 2018 | China   | Asia     | ###    | ###      | #####      |

# %% [markdown]
# ## More imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load & look at data

# %%
income = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--income_per_person_gdppercapita_ppp_inflation_adjusted--by--geo--time.csv')

# %%
lifespan = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--life_expectancy_years--by--geo--time.csv')

# %%
population = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--datapoints--population_total--by--geo--time.csv')

# %%
entities = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--entities--geo--country.csv')

# %%
concepts = pd.read_csv('https://raw.githubusercontent.com/open-numbers/ddf--gapminder--systema_globalis/master/ddf--concepts.csv')

# %%
income.shape, lifespan.shape, population.shape, entities.shape, concepts.shape
# Out:
# ((46513, 3), (44370, 3), (59297, 3), (273, 33), (590, 16))

# %%
income.head()
# Out:
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603

# %%
lifespan.head()
# Out:
#    geo  time  life_expectancy_years
# 0  abw  1800                  34.42
# 1  abw  1801                  34.42
# 2  abw  1802                  34.42
# 3  abw  1803                  34.42
# 4  abw  1804                  34.42

# %%
population.head()
# Out:
#    geo  time  population_total
# 0  afg  1800           3280000
# 1  afg  1801           3280000
# 2  afg  1802           3280000
# 3  afg  1803           3280000
# 4  afg  1804           3280000

# %%
pd.options.display.max_columns = 500
entities.head()
# Out:
#   country alt_5                    alternative_1 alternative_2 alternative_3  \
# 0    abkh   NaN                              NaN           NaN           NaN
# 1     abw   NaN                              NaN           NaN           NaN
# 2     afg   NaN  Islamic Republic of Afghanistan           NaN           NaN
# 3     ago   NaN                              NaN           NaN           NaN
# 4     aia   NaN                              NaN           NaN           NaN
#
#   alternative_4_cdiac arb1 arb2 arb3 arb4 arb5 arb6 g77_and_oecd_countries  \
# 0                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 1               Aruba  NaN  NaN  NaN  NaN  NaN  NaN                 others
# 2         Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 3              Angola  NaN  NaN  NaN  NaN  NaN  NaN                    g77
# 4                 NaN  NaN  NaN  NaN  NaN  NaN  NaN                 others
#
#   gapminder_list god_id gwid        income_groups  is--country  \
# 0       Abkhazia  GE-AB   i0                  NaN         True
# 1          Aruba     AW  i12          high_income         True
# 2    Afghanistan     AF   i1           low_income         True
# 3         Angola     AO   i7  upper_middle_income         True
# 4       Anguilla     AI   i8                  NaN         True
#
#   iso3166_1_alpha2 iso3166_1_alpha3  iso3166_1_numeric iso3166_2  landlocked  \
# 0              NaN              NaN                NaN       NaN         NaN
# 1               AW              ABW              533.0       NaN   coastline
# 2               AF              AFG                4.0       NaN  landlocked
# 3               AO              AGO               24.0       NaN   coastline
# 4               AI              AIA              660.0       NaN   coastline
#
#    latitude  longitude main_religion_2008         name        pandg  un_state  \
# 0       NaN        NaN                NaN     Abkhazia          NaN     False
# 1  12.50000  -69.96667          christian        Aruba          NaN     False
# 2  33.00000   66.00000             muslim  Afghanistan  AFGHANISTAN      True
# 3 -12.50000   18.50000          christian       Angola       ANGOLA      True
# 4  18.21667  -63.05000          christian     Anguilla          NaN     False
#
#   unicode_region_subtag upper_case_name world_4region        world_6region
# 0                   NaN             NaN        europe  europe_central_asia
# 1                    AW           ARUBA      americas              america
# 2                    AF     AFGHANISTAN          asia           south_asia
# 3                    AO          ANGOLA        africa   sub_saharan_africa
# 4                    AI        ANGUILLA      americas              america

# %%
concepts.head(20)
# Out:
#                                               concept color concept_type  \
# 0                   adults_with_hiv_percent_age_15_49   NaN      measure
# 1                           age_at_1st_marriage_women   NaN      measure
# 2                  aged_15_24_employment_rate_percent   NaN      measure
# 3                aged_15_24_unemployment_rate_percent   NaN      measure
# 4   aged_15_64_labour_force_participation_rate_per...   NaN      measure
# 5                 aged_15plus_employment_rate_percent   NaN      measure
# 6   aged_15plus_labour_force_participation_rate_pe...   NaN      measure
# 7               aged_15plus_unemployment_rate_percent   NaN      measure
# 8   aged_25_54_labour_force_participation_rate_per...   NaN      measure
# 9                aged_25_54_unemployment_rate_percent   NaN      measure
# 10               aged_55_64_unemployment_rate_percent   NaN      measure
# 11  aged_65plus_labour_force_participation_rate_pe...   NaN      measure
# 12              aged_65plus_unemployment_rate_percent   NaN      measure
# 13             agricultural_land_percent_of_land_area   NaN      measure
# 14     agricultural_water_withdrawal_percent_of_total   NaN      measure
# 15                         agriculture_percent_of_gdp   NaN      measure
# 16          agriculture_workers_percent_of_employment   NaN      measure
# 17                                  aid_given_2007_us   NaN      measure
# 18                       aid_given_per_person_2007_us   NaN      measure
# 19                           aid_given_percent_of_gni   NaN      measure
#
#                                           description description_long domain  \
# 0   The estimated percentage of adults aged 15 to ...              NaN    NaN
# 1   The mean age, in years, of first marriage for ...              NaN    NaN
# 2   Percentage of total population, age group 15-2...              NaN    NaN
# 3   Percentage of total population, age group 15-2...              NaN    NaN
# 4   For age group 15-64, percentage of all labour ...              NaN    NaN
# 5   Percentage of total population, age group 15+,...              NaN    NaN
# 6   For age group 15+, percentage of all labour to...              NaN    NaN
# 7   Percentage of total population, age group abov...              NaN    NaN
# 8   For age group 25-54, percentage of all labour ...              NaN    NaN
# 9   Percentage of total population, age group 25-5...              NaN    NaN
# 10  Percentage of total population, age group 55-6...              NaN    NaN
# 11  For age group 65+, percentage of all labour to...              NaN    NaN
# 12  Percentage of total population, age group abov...              NaN    NaN
# 13  Agricultural land refers to the share of land ...              NaN    NaN
# 14  Percentage of the total water withdrawal used ...              NaN    NaN
# 15  Agriculture corresponds to ISIC divisions 1-5 ...              NaN    NaN
# 16  Percentage of all employment that works in agr...              NaN    NaN
# 17  Total amount of allocable aid for official dev...              NaN    NaN
# 18  Total amount of official development assistanc...              NaN    NaN
# 19  Percentage of the gross national income (GNI) ...              NaN    NaN
#
#    drill_up indicator_url                                            name  \
# 0       NaN           NaN                  Adults with HIV (%, age 15-49)
# 1       NaN           NaN                     Age at 1st marriage (women)
# 2       NaN           NaN                  Aged 15-24 employment rate (%)
# 3       NaN           NaN                Aged 15-24 unemployment rate (%)
# 4       NaN           NaN  Aged 15-64 labour force participation rate (%)
# 5       NaN           NaN                    Aged 15+ employment rate (%)
# 6       NaN           NaN    Aged 15+ labour force participation rate (%)
# 7       NaN           NaN                  Aged 15+ unemployment rate (%)
# 8       NaN           NaN  Aged 25-54 labour force participation rate (%)
# 9       NaN           NaN                Aged 25-54 unemployment rate (%)
# 10      NaN           NaN                Aged 55-64 unemployment rate (%)
# 11      NaN           NaN    Aged 65+ labour force participation rate (%)
# 12      NaN           NaN                  Aged 65+ unemployment rate (%)
# 13      NaN           NaN              Agricultural land (% of land area)
# 14      NaN           NaN      Agricultural water withdrawal (% of total)
# 15      NaN           NaN                          Agriculture (% of GDP)
# 16      NaN           NaN           Agriculture workers (% of employment)
# 17      NaN           NaN                            Aid given (2007 US$)
# 18      NaN           NaN                 Aid given per person (2007 US$)
# 19      NaN           NaN                            Aid given (% of GNI)
#
#                       name_catalog                           name_short  \
# 0   Adults with HIV (%, age 15-49)                      Adults with HIV
# 1      Age at 1st marriage (women)                  Age at 1st marriage
# 2                       Aged 15-24                  Employment rate (%)
# 3                       Aged 15-24                Unemployment rate (%)
# 4                       Aged 15-64  Labour force participation rate (%)
# 5                         Aged 15+                  Employment rate (%)
# 6                         Aged 15+  Labour force participation rate (%)
# 7                         Aged 15+                Unemployment rate (%)
# 8                       Aged 25-54  Labour force participation rate (%)
# 9                       Aged 25-54                Unemployment rate (%)
# 10                      Aged 55-64                Unemployment rate (%)
# 11                        Aged 65+  Labour force participation rate (%)
# 12                        Aged 55+                Unemployment rate (%)
# 13               Agricultural land                    Agricultural land
# 14   Agricultural water withdrawal        Agricultural water withdrawal
# 15                     Agriculture                          Agriculture
# 16             Agriculture workers                  Agriculture workers
# 17                       Aid given                            Aid given
# 18            Aid given per person                 Aid given per person
# 19            Aid given (% of GNI)                 Aid given (% of GNI)
#
#                scales source source_long  \
# 0   ["log", "linear"]    NaN         NaN
# 1   ["linear", "log"]    NaN         NaN
# 2   ["linear", "log"]    NaN         NaN
# 3   ["linear", "log"]    NaN         NaN
# 4   ["linear", "log"]    NaN         NaN
# 5   ["linear", "log"]    NaN         NaN
# 6   ["linear", "log"]    NaN         NaN
# 7   ["linear", "log"]    NaN         NaN
# 8   ["linear", "log"]    NaN         NaN
# 9   ["linear", "log"]    NaN         NaN
# 10  ["linear", "log"]    NaN         NaN
# 11  ["linear", "log"]    NaN         NaN
# 12  ["linear", "log"]    NaN         NaN
# 13  ["linear", "log"]    NaN         NaN
# 14  ["linear", "log"]    NaN         NaN
# 15  ["linear", "log"]    NaN         NaN
# 16  ["linear", "log"]    NaN         NaN
# 17  ["linear", "log"]    NaN         NaN
# 18  ["linear", "log"]    NaN         NaN
# 19  ["linear", "log"]    NaN         NaN
#
#                                            source_url  \
# 0   https://www.gapminder.org/gapminder-world/docu...
# 1   https://www.gapminder.org/data/documentation/g...
# 2                        https://www.ilo.org/ilostat/
# 3                        https://www.ilo.org/ilostat/
# 4                        https://www.ilo.org/ilostat/
# 5                        https://www.ilo.org/ilostat/
# 6                        https://www.ilo.org/ilostat/
# 7                        https://www.ilo.org/ilostat/
# 8                        https://www.ilo.org/ilostat/
# 9                        https://www.ilo.org/ilostat/
# 10                       https://www.ilo.org/ilostat/
# 11                       https://www.ilo.org/ilostat/
# 12                       https://www.ilo.org/ilostat/
# 13  https://data.worldbank.org/indicator/AG.LND.AG...
# 14  http://www.fao.org/nr/water/aquastat/data/quer...
# 15  https://data.worldbank.org/indicator/NV.AGR.TO...
# 16                       https://www.ilo.org/ilostat/
# 17                            https://stats.oecd.org/
# 18                            https://stats.oecd.org/
# 19                            https://stats.oecd.org/
#
#                           tags
# 0                          hiv
# 1                   population
# 2              employment_rate
# 3                 unemployment
# 4   labour_force_participation
# 5              employment_rate
# 6   labour_force_participation
# 7                 unemployment
# 8   labour_force_participation
# 9                 unemployment
# 10                unemployment
# 11  labour_force_participation
# 12                unemployment
# 13                   geography
# 14           environment_water
# 15                     sectors
# 16        employment_by_sector
# 17                   aid_given
# 18                   aid_given
# 19                   aid_given

# %% [markdown]
# ## Merge data

# %% [markdown]
# https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf

# %%
print(income.shape)
print(lifespan.shape)
# Out:
# (46513, 3)
# (44370, 3)

# %%
merged = pd.merge(income, lifespan)

# %%
print(merged.shape)
merged.head()
# Out:
# (40437, 4)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years
# 0                  28.21
# 1                  28.20
# 2                  28.19
# 3                  28.18
# 4                  28.17

# %%
merged.duplicated(subset=['geo', 'time']).value_counts()
# Out:
# False    40437
# dtype: int64

# %%
merged['geo'].nunique() == len(merged['geo'])
# Out:
# False

# %%
df = pd.merge(merged, population)

# %%
print(df.shape)
df.head()
# Out:
# (40437, 5)
#    geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0  afg  1800                                                603
# 1  afg  1801                                                603
# 2  afg  1802                                                603
# 3  afg  1803                                                603
# 4  afg  1804                                                603
#
#    life_expectancy_years  population_total
# 0                  28.21           3280000
# 1                  28.20           3280000
# 2                  28.19           3280000
# 3                  28.18           3280000
# 4                  28.17           3280000

# %%
df1 = pd.merge(df, entities[['country','name', 'world_4region', 'world_6region']], left_on='geo', right_on='country')

# %%
df1
# Out:
#        geo  time  income_per_person_gdppercapita_ppp_inflation_adjusted  \
# 0      afg  1800                                                603
# 1      afg  1801                                                603
# 2      afg  1802                                                603
# 3      afg  1803                                                603
# 4      afg  1804                                                603
# 5      afg  1805                                                603
# 6      afg  1806                                                603
# 7      afg  1807                                                603
# 8      afg  1808                                                603
# 9      afg  1809                                                603
# 10     afg  1810                                                604
# 11     afg  1811                                                604
# 12     afg  1812                                                604
# 13     afg  1813                                                604
# 14     afg  1814                                                604
# 15     afg  1815                                                604
# 16     afg  1816                                                604
# 17     afg  1817                                                604
# 18     afg  1818                                                604
# 19     afg  1819                                                604
# 20     afg  1820                                                604
# 21     afg  1821                                                607
# 22     afg  1822                                                609
# 23     afg  1823                                                611
# 24     afg  1824                                                613
# 25     afg  1825                                                615
# 26     afg  1826                                                617
# 27     afg  1827                                                619
# 28     afg  1828                                                621
# 29     afg  1829                                                623
# ...    ...   ...                                                ...
# 40407  zwe  1989                                               2494
# 40408  zwe  1990                                               2593
# 40409  zwe  1991                                               2668
# 40410  zwe  1992                                               2373
# 40411  zwe  1993                                               2349
# 40412  zwe  1994                                               2517
# 40413  zwe  1995                                               2476
# 40414  zwe  1996                                               2685
# 40415  zwe  1997                                               2712
# 40416  zwe  1998                                               2748
# 40417  zwe  1999                                               2686
# 40418  zwe  2000                                               2571
# 40419  zwe  2001                                               2577
# 40420  zwe  2002                                               2323
# 40421  zwe  2003                                               1908
# 40422  zwe  2004                                               1777
# 40423  zwe  2005                                               1654
# 40424  zwe  2006                                               1575
# 40425  zwe  2007                                               1494
# 40426  zwe  2008                                               1209
# 40427  zwe  2009                                               1290
# 40428  zwe  2010                                               1460
# 40429  zwe  2011                                               1663
# 40430  zwe  2012                                               1848
# 40431  zwe  2013                                               1901
# 40432  zwe  2014                                               1908
# 40433  zwe  2015                                               1891
# 40434  zwe  2016                                               1860
# 40435  zwe  2017                                               1907
# 40436  zwe  2018                                               1952
#
#        life_expectancy_years  population_total country         name  \
# 0                      28.21           3280000     afg  Afghanistan
# 1                      28.20           3280000     afg  Afghanistan
# 2                      28.19           3280000     afg  Afghanistan
# 3                      28.18           3280000     afg  Afghanistan
# 4                      28.17           3280000     afg  Afghanistan
# 5                      28.16           3280000     afg  Afghanistan
# 6                      28.15           3280000     afg  Afghanistan
# 7                      28.14           3280000     afg  Afghanistan
# 8                      28.13           3280000     afg  Afghanistan
# 9                      28.12           3280000     afg  Afghanistan
# 10                     28.11           3280000     afg  Afghanistan
# 11                     28.10           3280779     afg  Afghanistan
# 12                     28.09           3282342     afg  Afghanistan
# 13                     28.08           3284692     afg  Afghanistan
# 14                     28.07           3287834     afg  Afghanistan
# 15                     28.06           3291770     afg  Afghanistan
# 16                     28.05           3296506     afg  Afghanistan
# 17                     28.04           3302044     afg  Afghanistan
# 18                     28.03           3308390     afg  Afghanistan
# 19                     28.02           3315547     afg  Afghanistan
# 20                     28.01           3323519     afg  Afghanistan
# 21                     28.00           3332311     afg  Afghanistan
# 22                     27.99           3341926     afg  Afghanistan
# 23                     27.98           3352368     afg  Afghanistan
# 24                     27.97           3363642     afg  Afghanistan
# 25                     27.95           3375751     afg  Afghanistan
# 26                     27.94           3388701     afg  Afghanistan
# 27                     27.93           3402494     afg  Afghanistan
# 28                     27.92           3417136     afg  Afghanistan
# 29                     27.91           3432630     afg  Afghanistan
# ...                      ...               ...     ...          ...
# 40407                  62.69           9902540     zwe     Zimbabwe
# 40408                  61.69          10183113     zwe     Zimbabwe
# 40409                  61.04          10443043     zwe     Zimbabwe
# 40410                  59.41          10682868     zwe     Zimbabwe
# 40411                  57.58          10905756     zwe     Zimbabwe
# 40412                  55.78          11116948     zwe     Zimbabwe
# 40413                  53.69          11320346     zwe     Zimbabwe
# 40414                  52.23          11518262     zwe     Zimbabwe
# 40415                  50.75          11709997     zwe     Zimbabwe
# 40416                  49.12          11893272     zwe     Zimbabwe
# 40417                  47.81          12064537     zwe     Zimbabwe
# 40418                  46.69          12222251     zwe     Zimbabwe
# 40419                  46.20          12366165     zwe     Zimbabwe
# 40420                  45.58          12500525     zwe     Zimbabwe
# 40421                  45.34          12633897     zwe     Zimbabwe
# 40422                  45.06          12777511     zwe     Zimbabwe
# 40423                  45.31          12940032     zwe     Zimbabwe
# 40424                  45.70          13124267     zwe     Zimbabwe
# 40425                  46.38          13329909     zwe     Zimbabwe
# 40426                  46.71          13558469     zwe     Zimbabwe
# 40427                  47.55          13810599     zwe     Zimbabwe
# 40428                  49.57          14086317     zwe     Zimbabwe
# 40429                  51.90          14386649     zwe     Zimbabwe
# 40430                  54.06          14710826     zwe     Zimbabwe
# 40431                  55.59          15054506     zwe     Zimbabwe
# 40432                  56.99          15411675     zwe     Zimbabwe
# 40433                  58.27          15777451     zwe     Zimbabwe
# 40434                  59.27          16150362     zwe     Zimbabwe
# 40435                  59.80          16529904     zwe     Zimbabwe
# 40436                  60.18          16913261     zwe     Zimbabwe
#
#       world_4region       world_6region
# 0              asia          south_asia
# 1              asia          south_asia
# 2              asia          south_asia
# 3              asia          south_asia
# 4              asia          south_asia
# 5              asia          south_asia
# 6              asia          south_asia
# 7              asia          south_asia
# 8              asia          south_asia
# 9              asia          south_asia
# 10             asia          south_asia
# 11             asia          south_asia
# 12             asia          south_asia
# 13             asia          south_asia
# 14             asia          south_asia
# 15             asia          south_asia
# 16             asia          south_asia
# 17             asia          south_asia
# 18             asia          south_asia
# 19             asia          south_asia
# 20             asia          south_asia
# 21             asia          south_asia
# 22             asia          south_asia
# 23             asia          south_asia
# 24             asia          south_asia
# 25             asia          south_asia
# 26             asia          south_asia
# 27             asia          south_asia
# 28             asia          south_asia
# 29             asia          south_asia
# ...             ...                 ...
# 40407        africa  sub_saharan_africa
# 40408        africa  sub_saharan_africa
# 40409        africa  sub_saharan_africa
# 40410        africa  sub_saharan_africa
# 40411        africa  sub_saharan_africa
# 40412        africa  sub_saharan_africa
# 40413        africa  sub_saharan_africa
# 40414        africa  sub_saharan_africa
# 40415        africa  sub_saharan_africa
# 40416        africa  sub_saharan_africa
# 40417        africa  sub_saharan_africa
# 40418        africa  sub_saharan_africa
# 40419        africa  sub_saharan_africa
# 40420        africa  sub_saharan_africa
# 40421        africa  sub_saharan_africa
# 40422        africa  sub_saharan_africa
# 40423        africa  sub_saharan_africa
# 40424        africa  sub_saharan_africa
# 40425        africa  sub_saharan_africa
# 40426        africa  sub_saharan_africa
# 40427        africa  sub_saharan_africa
# 40428        africa  sub_saharan_africa
# 40429        africa  sub_saharan_africa
# 40430        africa  sub_saharan_africa
# 40431        africa  sub_saharan_africa
# 40432        africa  sub_saharan_africa
# 40433        africa  sub_saharan_africa
# 40434        africa  sub_saharan_africa
# 40435        africa  sub_saharan_africa
# 40436        africa  sub_saharan_africa
#
# [40437 rows x 9 columns]

# %%
df1 = df1.rename(columns = {
   'country': 'country_code',
   'time': 'year',
   'income_per_person_gdppercapita_ppp_inflation_adjusted': 'income',
   'life_expectancy_years': 'lifespan',
   'population_total': 'population',
   'name': 'country',
   'world_6region': '6region',
   'world_4region': '4region'
})
df1.head()
# Out:
#    geo  year  income  lifespan  population country_code      country 4region  \
# 0  afg  1800     603     28.21     3280000          afg  Afghanistan    asia
# 1  afg  1801     603     28.20     3280000          afg  Afghanistan    asia
# 2  afg  1802     603     28.19     3280000          afg  Afghanistan    asia
# 3  afg  1803     603     28.18     3280000          afg  Afghanistan    asia
# 4  afg  1804     603     28.17     3280000          afg  Afghanistan    asia
#
#       6region
# 0  south_asia
# 1  south_asia
# 2  south_asia
# 3  south_asia
# 4  south_asia

# %% [markdown]
# ## Explore data

# %%
df1.dtypes
# Out:
# geo              object
# year              int64
# income            int64
# lifespan        float64
# population        int64
# country_code     object
# country          object
# 4region          object
# 6region          object
# dtype: object

# %%
df1.describe()
# Out:
#                year         income      lifespan    population
# count  40437.000000   40437.000000  40437.000000  4.043700e+04
# mean    1909.292900    4619.492717     43.132080  1.371204e+07
# std       63.308682   10209.571045     16.313228  6.606335e+07
# min     1800.000000     247.000000      1.000000  2.128000e+03
# 25%     1854.000000     876.000000     31.160000  4.113310e+05
# 50%     1909.000000    1442.000000     35.500000  1.985952e+06
# 75%     1964.000000    3488.000000     55.970000  6.499707e+06
# max     2018.000000  177522.000000     84.170000  1.415046e+09

# %%
usa = df1[df1.country == 'United States']
usa.head()
# Out:
#        geo  year  income  lifespan  population country_code        country  \
# 38028  usa  1800    2127     39.41     6801854          usa  United States
# 38029  usa  1801    2167     39.41     6933517          usa  United States
# 38030  usa  1802    2202     39.41     7067728          usa  United States
# 38031  usa  1803    2166     39.41     7204538          usa  United States
# 38032  usa  1804    2165     39.41     7343995          usa  United States
#
#         4region  6region
# 38028  americas  america
# 38029  americas  america
# 38030  americas  america
# 38031  americas  america
# 38032  americas  america

# %%
usa.describe()
# Out:
#               year        income    lifespan    population
# count   219.000000    219.000000  219.000000  2.190000e+02
# mean   1909.000000  14572.936073   54.846256  1.163662e+08
# std      63.364028  15066.042247   15.202079  9.738644e+07
# min    1800.000000   2113.000000   31.000000  6.801854e+06
# 25%    1854.500000   3512.500000   39.410000  2.752198e+07
# 50%    1909.000000   7989.000000   51.780000  9.236198e+07
# 75%    1963.500000  20090.500000   70.270000  1.962540e+08
# max    2018.000000  54898.000000   79.140000  3.267667e+08

# %%
usa1 = usa[usa.year.isin([1818, 1918, 2018])]

# %%
china = df1[df1.country == 'China']

# %%
china.describe()
# Out:
#               year        income    lifespan    population
# count   219.000000    219.000000  219.000000  2.190000e+02
# mean   1909.000000   1735.100457   41.437489  6.060697e+08
# std      63.364028   2583.720237   15.799616  3.308813e+08
# min    1800.000000    530.000000   22.130000  3.216750e+08
# 25%    1854.500000    935.000000   31.790000  3.842179e+08
# 50%    1909.000000    985.000000   32.000000  4.216460e+08
# 75%    1963.500000   1055.000000   51.345000  6.993707e+08
# max    2018.000000  16018.000000   76.920000  1.415046e+09

# %%
china1 = china[china.year.isin([1818, 1918, 2018])]

# %%
usa1.set_index('year')
# Out:
#       geo  income  lifespan  population country_code        country   4region  \
# year
# 1818  usa    2258     39.41     9879049          usa  United States  americas
# 1918  usa    9371     47.18   106721812          usa  United States  americas
# 2018  usa   54898     79.14   326766748          usa  United States  americas
#
#       6region
# year
# 1818  america
# 1918  america
# 2018  america

# %%
china1.set_index('year')
# Out:
#       geo  income  lifespan  population country_code country 4region  \
# year
# 1818  chn     985     32.00   374161494          chn   China    asia
# 1918  chn     989     22.13   462444535          chn   China    asia
# 2018  chn   16018     76.92  1415045928          chn   China    asia
#
#                 6region
# year
# 1818  east_asia_pacific
# 1918  east_asia_pacific
# 2018  east_asia_pacific

# %%
china_usa = pd.concat(usa1, china1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-65e421747386> in <module>()
# ----> 1 china_usa = pd.concat(usa1, china1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     242             raise TypeError('first argument must be an iterable of pandas '
#     243                             'objects, you passed an object of type '
# --> 244                             '"{name}"'.format(name=type(objs).__name__))
#     245
#     246         if join == 'outer':
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %% [markdown]
# ## Plot visualization

# %%
import seaborn as sns

now = df1[df1.year == 2018]

now.head()
# Out:
#       geo  year  income  lifespan  population country_code  \
# 218   afg  2018    1867     58.69    36373176          afg
# 437   ago  2018    5846     65.19    30774205          ago
# 656   alb  2018   12424     78.01     2934363          alb
# 922   are  2018   68231     76.89     9541615          are
# 1141  arg  2018   18942     76.97    44688864          arg
#
#                    country   4region                   6region
# 218            Afghanistan      asia                south_asia
# 437                 Angola    africa        sub_saharan_africa
# 656                Albania    europe       europe_central_asia
# 922   United Arab Emirates      asia  middle_east_north_africa
# 1141             Argentina  americas                   america

# %%
sns.relplot(x='income', y='lifespan', hue='6region', size='population', 
            data=now, sizes=(30,400), palette='muted', alpha=.7)
plt.xscale('log')
plt.title('The World in 2018');

# %%
fig, ax = plt.subplots(figsize=(8,8))

sns.relplot(x='income', y='lifespan', hue='4region', size='population', 
                  data=now, sizes=(30, 500), alpha=.7)

# %% [markdown]
# ## Analyze outliers

# %% [markdown]
# ## Plot multiple years

# %% [markdown]
# ## Point out a story
